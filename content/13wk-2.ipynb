# %% [raw]
# ---
# title: "13wk-2: [DataFrame] -- FIFA22 데이터 // 숙제"
# author: "최규빈"
# date: "05/29/2025"
# draft: false
# ---

# %% [markdown]
# {{<video https://youtu.be/playlist?list=PLQqh36zP38-yMQ_DWi4dNXO-TcvRWsEpe&si=hOepRoFD05vAS_pT>}}

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 1. FIFA22데이터

# %% [markdown]
# ### A. Data

# %% [markdown]
# `-` 데이터 load

# %%
df = pd.read_csv('FIFA22_official_data.csv')
df
# Out:
#            ID             Name  Age  \
# 0      212198  Bruno Fernandes   26
# 1      209658      L. Goretzka   26
# 2      176580        L. Suárez   34
# 3      192985     K. De Bruyne   30
# 4      224334         M. Acuña   29
# ...       ...              ...  ...
# 16705  240558    18 L. Clayton   17
# 16706  262846         �. Dobre   20
# 16707  241317   21 Xue Qinghao   19
# 16708  259646        A. Shaikh   18
# 16709  178453    07 A. Censori   17
#
#                                                   Photo Nationality  \
# 0      https://cdn.sofifa.com/players/212/198/22_60.png    Portugal
# 1      https://cdn.sofifa.com/players/209/658/22_60.png     Germany
# 2      https://cdn.sofifa.com/players/176/580/22_60.png     Uruguay
# 3      https://cdn.sofifa.com/players/192/985/22_60.png     Belgium
# 4      https://cdn.sofifa.com/players/224/334/22_60.png   Argentina
# ...                                                 ...         ...
# 16705  https://cdn.sofifa.com/players/240/558/18_60.png     England
# 16706  https://cdn.sofifa.com/players/262/846/22_60.png     Romania
# 16707  https://cdn.sofifa.com/players/241/317/21_60.png    China PR
# 16708  https://cdn.sofifa.com/players/259/646/22_60.png       India
# 16709  https://cdn.sofifa.com/players/178/453/07_60.png       Italy
#
#                                           Flag  Overall  Potential  \
# 0          https://cdn.sofifa.com/flags/pt.png       88         89
# 1          https://cdn.sofifa.com/flags/de.png       87         88
# 2          https://cdn.sofifa.com/flags/uy.png       88         88
# 3          https://cdn.sofifa.com/flags/be.png       91         91
# 4          https://cdn.sofifa.com/flags/ar.png       84         84
# ...                                        ...      ...        ...
# 16705  https://cdn.sofifa.com/flags/gb-eng.png       53         70
# 16706      https://cdn.sofifa.com/flags/ro.png       53         63
# 16707      https://cdn.sofifa.com/flags/cn.png       47         60
# 16708      https://cdn.sofifa.com/flags/in.png       47         67
# 16709      https://cdn.sofifa.com/flags/it.png       28         38
#
#                         Club                                   Club Logo  ...  \
# 0          Manchester United      https://cdn.sofifa.com/teams/11/30.png  ...
# 1          FC Bayern München      https://cdn.sofifa.com/teams/21/30.png  ...
# 2         Atlético de Madrid     https://cdn.sofifa.com/teams/240/30.png  ...
# 3            Manchester City      https://cdn.sofifa.com/teams/10/30.png  ...
# 4                 Sevilla FC     https://cdn.sofifa.com/teams/481/30.png  ...
# ...                      ...                                         ...  ...
# 16705        Cheltenham Town    https://cdn.sofifa.com/teams/1936/30.png  ...
# 16706  FC Academica Clinceni  https://cdn.sofifa.com/teams/113391/30.png  ...
# 16707    Shanghai Shenhua FC  https://cdn.sofifa.com/teams/110955/30.png  ...
# 16708     ATK Mohun Bagan FC  https://cdn.sofifa.com/teams/113146/30.png  ...
# 16709                 Arezzo  https://cdn.sofifa.com/teams/110907/30.png  ...
#
#       SlidingTackle GKDiving  GKHandling GKKicking  GKPositioning  GKReflexes  \
# 0              65.0     12.0        14.0      15.0            8.0        14.0
# 1              77.0     13.0         8.0      15.0           11.0         9.0
# 2              38.0     27.0        25.0      31.0           33.0        37.0
# 3              53.0     15.0        13.0       5.0           10.0        13.0
# 4              82.0      8.0        14.0      13.0           13.0        14.0
# ...             ...      ...         ...       ...            ...         ...
# 16705          12.0     55.0        54.0      52.0           50.0        59.0
# 16706          12.0     57.0        52.0      53.0           48.0        58.0
# 16707           9.0     49.0        48.0      45.0           38.0        52.0
# 16708          13.0     49.0        41.0      39.0           45.0        49.0
# 16709           NaN      7.0         1.0      36.0            6.0         9.0
#
#        Best Position Best Overall Rating Release Clause DefensiveAwareness
# 0                CAM                88.0        €206.9M               72.0
# 1                 CM                87.0        €160.4M               74.0
# 2                 ST                88.0         €91.2M               42.0
# 3                 CM                91.0        €232.2M               68.0
# 4                 LB                84.0         €77.7M               80.0
# ...              ...                 ...            ...                ...
# 16705             GK                52.0          €238K                NaN
# 16706             GK                53.0          €279K                5.0
# 16707             GK                47.0          €223K               21.0
# 16708             GK                47.0          €259K                7.0
# 16709             ST                36.0            NaN                NaN
#
# [16710 rows x 65 columns]

# %% [markdown]
# :::{.callout-note}
# **기본정보**
#
# | 컬럼명 | 설명 |
# |--------|------|
# | `ID` | 선수 고유 식별 번호 |
# | `Name` | 선수 이름 |
# | `Age` | 나이 |
# | `Photo` | 선수 얼굴 사진 (URL 또는 이미지 경로) |
# | `Nationality` | 국적 |
# | `Flag` | 국가의 국기 이미지 (URL 또는 이미지 경로) |
# | `Club` | 소속 클럽 |
# | `Club Logo` | 클럽 로고 이미지 (URL 또는 경로) |
# | `Value` | 시장 가치 (예: €50M 등) |
# | `Wage` | 주급 (예: €200K 등) |
# | `Release Clause` | 바이아웃 금액, 계약 해지에 필요한 금액 |
#
# **전체능력치 및 잠재력**
#
# | 컬럼명 | 설명 |
# |--------|------|
# | `Overall` | 현재 종합 능력치 (게임 내 평점 기준) |
# | `Potential` | 향후 성장 가능성이 반영된 잠재 평점 |
# | `Special` | 특수 능력치 총합 (비공식) |
# | `Best Overall Rating` | 가장 높은 능력을 발휘할 수 있는 포지션에서의 최고 평점 |
# | `Best Position` | 가장 잘하는 포지션 |
#
# **플레이관련**
#
# | 컬럼명 | 설명 |
# |--------|------|
# | `Preferred Foot` | 선호하는 발 (Left/Right) |
# | `International Reputation` | 국제적인 명성 (1~5점) |
# | `Weak Foot` | 약발 능력치 (1~5점, 높을수록 양발잡이) |
# | `Skill Moves` | 개인기 기술 수준 (1~5점) |
# | `Work Rate` | 공격/수비 성향 (예: High/Medium) |
# | `Body Type` | 체형 (예: Lean, Normal, Stocky) |
# | `Real Face` | 실제 얼굴 스캔 여부 (Yes/No) |
# | `Position` | 주 포지션 (예: ST, CM, GK 등) |
# | `Jersey Number` | 등번호 |
# | `Joined` | 클럽에 입단한 날짜 |
# | `Loaned From` | 임대 중인 경우 원 소속 클럽 |
# | `Contract Valid Until` | 계약 만료 연도 |
#
# **신체 정보**
#
# | 컬럼명 | 설명 |
# |--------|------|
# | `Height` | 키 (cm 또는 ft/in) |
# | `Weight` | 몸무게 (kg 또는 lbs) |
#
# **세부능력치**
#
# | 컬럼명 | 설명 |
# |--------|------|
# | `Crossing` | 크로스 정확도 |
# | `Finishing` | 골 결정력 |
# | `HeadingAccuracy` | 헤딩 정확도 |
# | `ShortPassing` | 짧은 패스 정확도 |
# | `Volleys` | 발리 슛 능력 |
# | `Dribbling` | 드리블 능력 |
# | `Curve` | 감아차기 능력 |
# | `FKAccuracy` | 프리킥 정확도 |
# | `LongPassing` | 롱패스 능력 |
# | `BallControl` | 볼 컨트롤 능력 |
# | `Acceleration` | 가속력 |
# | `SprintSpeed` | 최고 속도 |
# | `Agility` | 민첩성 |
# | `Reactions` | 반응 속도 |
# | `Balance` | 균형 감각 |
# | `ShotPower` | 슛 파워 |
# | `Jumping` | 점프력 |
# | `Stamina` | 체력 |
# | `Strength` | 몸싸움 능력 |
# | `LongShots` | 중거리 슛 능력 |
# | `Aggression` | 공격성 |
# | `Interceptions` | 공 차단 능력 |
# | `Positioning` | 위치 선정 |
# | `Vision` | 시야 |
# | `Penalties` | 페널티킥 능력 |
# | `Composure` | 침착성 |
# | `Marking` | 마크 능력 |
# | `StandingTackle` | 서서 태클 능력 |
# | `SlidingTackle` | 슬라이딩 태클 능력 |
# | `DefensiveAwareness` | 수비 인식 (FIFA 22 이후 명시됨) |
# | `GKDiving` | 다이빙 |
# | `GKHandling` | 캐치 능력 |
# | `GKKicking` | 킥 정확도 |
# | `GKPositioning` | 골키퍼 위치 선정 |
# | `GKReflexes` | 반사 신경 |
# :::

# %% [markdown]
# ### B. 결측치정리

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16710 entries, 0 to 16709
# Data columns (total 65 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        16710 non-null  int64
#  1   Name                      16710 non-null  object
#  2   Age                       16710 non-null  int64
#  3   Photo                     16710 non-null  object
#  4   Nationality               16710 non-null  object
#  5   Flag                      16710 non-null  object
#  6   Overall                   16710 non-null  int64
#  7   Potential                 16710 non-null  int64
#  8   Club                      16446 non-null  object
#  9   Club Logo                 16710 non-null  object
#  10  Value                     16710 non-null  object
#  11  Wage                      16710 non-null  object
#  12  Special                   16710 non-null  int64
#  13  Preferred Foot            16710 non-null  object
#  14  International Reputation  16710 non-null  float64
#  15  Weak Foot                 16710 non-null  float64
#  16  Skill Moves               16710 non-null  float64
#  17  Work Rate                 16710 non-null  object
#  18  Body Type                 16681 non-null  object
#  19  Real Face                 16681 non-null  object
#  20  Position                  16684 non-null  object
#  21  Jersey Number             16684 non-null  float64
#  22  Joined                    15198 non-null  object
#  23  Loaned From               1132 non-null   object
#  24  Contract Valid Until      16359 non-null  object
#  25  Height                    16710 non-null  object
#  26  Weight                    16710 non-null  object
#  27  Crossing                  16710 non-null  float64
#  28  Finishing                 16710 non-null  float64
#  29  HeadingAccuracy           16710 non-null  float64
#  30  ShortPassing              16710 non-null  float64
#  31  Volleys                   16673 non-null  float64
#  32  Dribbling                 16710 non-null  float64
#  33  Curve                     16673 non-null  float64
#  34  FKAccuracy                16710 non-null  float64
#  35  LongPassing               16710 non-null  float64
#  36  BallControl               16710 non-null  float64
#  37  Acceleration              16710 non-null  float64
#  38  SprintSpeed               16710 non-null  float64
#  39  Agility                   16673 non-null  float64
#  40  Reactions                 16710 non-null  float64
#  41  Balance                   16673 non-null  float64
#  42  ShotPower                 16710 non-null  float64
#  43  Jumping                   16673 non-null  float64
#  44  Stamina                   16710 non-null  float64
#  45  Strength                  16710 non-null  float64
#  46  LongShots                 16710 non-null  float64
#  47  Aggression                16710 non-null  float64
#  48  Interceptions             16702 non-null  float64
#  49  Positioning               16702 non-null  float64
#  50  Vision                    16673 non-null  float64
#  51  Penalties                 16710 non-null  float64
#  52  Composure                 16459 non-null  float64
#  53  Marking                   892 non-null    float64
#  54  StandingTackle            16710 non-null  float64
#  55  SlidingTackle             16673 non-null  float64
#  56  GKDiving                  16710 non-null  float64
#  57  GKHandling                16710 non-null  float64
#  58  GKKicking                 16710 non-null  float64
#  59  GKPositioning             16710 non-null  float64
#  60  GKReflexes                16710 non-null  float64
#  61  Best Position             16710 non-null  object
#  62  Best Overall Rating       16710 non-null  float64
#  63  Release Clause            14961 non-null  object
#  64  DefensiveAwareness        15818 non-null  float64
# dtypes: float64(40), int64(5), object(20)
# memory usage: 8.3+ MB

# %%
df.isna().sum().sort_values()
# Out:
# ID                        0
# Name                      0
# Age                       0
# Photo                     0
# Nationality               0
#                       ...
# DefensiveAwareness      892
# Joined                 1512
# Release Clause         1749
# Loaned From           15578
# Marking               15818
# Length: 65, dtype: int64

# %%
df2 = df.drop(["Loaned From", "Marking"], axis=1).dropna()
df2
# Out:
#            ID             Name  Age  \
# 0      212198  Bruno Fernandes   26
# 1      209658      L. Goretzka   26
# 2      176580        L. Suárez   34
# 3      192985     K. De Bruyne   30
# 4      224334         M. Acuña   29
# ...       ...              ...  ...
# 16703  259718      F. Gebhardt   19
# 16704  251433          B. Voll   20
# 16706  262846         �. Dobre   20
# 16707  241317   21 Xue Qinghao   19
# 16708  259646        A. Shaikh   18
#
#                                                   Photo Nationality  \
# 0      https://cdn.sofifa.com/players/212/198/22_60.png    Portugal
# 1      https://cdn.sofifa.com/players/209/658/22_60.png     Germany
# 2      https://cdn.sofifa.com/players/176/580/22_60.png     Uruguay
# 3      https://cdn.sofifa.com/players/192/985/22_60.png     Belgium
# 4      https://cdn.sofifa.com/players/224/334/22_60.png   Argentina
# ...                                                 ...         ...
# 16703  https://cdn.sofifa.com/players/259/718/22_60.png     Germany
# 16704  https://cdn.sofifa.com/players/251/433/22_60.png     Germany
# 16706  https://cdn.sofifa.com/players/262/846/22_60.png     Romania
# 16707  https://cdn.sofifa.com/players/241/317/21_60.png    China PR
# 16708  https://cdn.sofifa.com/players/259/646/22_60.png       India
#
#                                       Flag  Overall  Potential  \
# 0      https://cdn.sofifa.com/flags/pt.png       88         89
# 1      https://cdn.sofifa.com/flags/de.png       87         88
# 2      https://cdn.sofifa.com/flags/uy.png       88         88
# 3      https://cdn.sofifa.com/flags/be.png       91         91
# 4      https://cdn.sofifa.com/flags/ar.png       84         84
# ...                                    ...      ...        ...
# 16703  https://cdn.sofifa.com/flags/de.png       52         66
# 16704  https://cdn.sofifa.com/flags/de.png       58         69
# 16706  https://cdn.sofifa.com/flags/ro.png       53         63
# 16707  https://cdn.sofifa.com/flags/cn.png       47         60
# 16708  https://cdn.sofifa.com/flags/in.png       47         67
#
#                         Club                                   Club Logo  ...  \
# 0          Manchester United      https://cdn.sofifa.com/teams/11/30.png  ...
# 1          FC Bayern München      https://cdn.sofifa.com/teams/21/30.png  ...
# 2         Atlético de Madrid     https://cdn.sofifa.com/teams/240/30.png  ...
# 3            Manchester City      https://cdn.sofifa.com/teams/10/30.png  ...
# 4                 Sevilla FC     https://cdn.sofifa.com/teams/481/30.png  ...
# ...                      ...                                         ...  ...
# 16703          FC Basel 1893     https://cdn.sofifa.com/teams/896/30.png  ...
# 16704     F.C. Hansa Rostock      https://cdn.sofifa.com/teams/27/30.png  ...
# 16706  FC Academica Clinceni  https://cdn.sofifa.com/teams/113391/30.png  ...
# 16707    Shanghai Shenhua FC  https://cdn.sofifa.com/teams/110955/30.png  ...
# 16708     ATK Mohun Bagan FC  https://cdn.sofifa.com/teams/113146/30.png  ...
#
#       SlidingTackle GKDiving  GKHandling GKKicking  GKPositioning  GKReflexes  \
# 0              65.0     12.0        14.0      15.0            8.0        14.0
# 1              77.0     13.0         8.0      15.0           11.0         9.0
# 2              38.0     27.0        25.0      31.0           33.0        37.0
# 3              53.0     15.0        13.0       5.0           10.0        13.0
# 4              82.0      8.0        14.0      13.0           13.0        14.0
# ...             ...      ...         ...       ...            ...         ...
# 16703          10.0     53.0        45.0      47.0           52.0        57.0
# 16704          10.0     59.0        60.0      56.0           55.0        61.0
# 16706          12.0     57.0        52.0      53.0           48.0        58.0
# 16707           9.0     49.0        48.0      45.0           38.0        52.0
# 16708          13.0     49.0        41.0      39.0           45.0        49.0
#
#        Best Position Best Overall Rating Release Clause DefensiveAwareness
# 0                CAM                88.0        €206.9M               72.0
# 1                 CM                87.0        €160.4M               74.0
# 2                 ST                88.0         €91.2M               42.0
# 3                 CM                91.0        €232.2M               68.0
# 4                 LB                84.0         €77.7M               80.0
# ...              ...                 ...            ...                ...
# 16703             GK                52.0          €361K                6.0
# 16704             GK                58.0          €656K                5.0
# 16706             GK                53.0          €279K                5.0
# 16707             GK                47.0          €223K               21.0
# 16708             GK                47.0          €259K                7.0
#
# [14398 rows x 63 columns]

# %% [markdown]
# ### C. 포지션 정리

# %% [markdown]
# `-` 포지션변환

# %%
df3 = df2.copy()

# %%
df3['Position'] = [l.split(">")[-1] for l in df2.Position]
df3.Position
# Out:
# 0        CAM
# 1        LDM
# 2         RS
# 3        RCM
# 4         LB
#         ...
# 16703    RES
# 16704    RES
# 16706    RES
# 16707    RES
# 16708    SUB
# Name: Position, Length: 14398, dtype: object

# %% [markdown]
# `-` 포지션치환

# %%
position_dict = {
    'GOALKEEPER':{'GK'},
    'DEFENDER':{'CB','RCB','LCB','RB','LB','RWB','LWB'},
    'MIDFIELDER':{'CM','RCM','LCM','CDM','RDM','LDM','CAM','RAM','LAM','RM','LM'},
    'FORWARD':{'ST','CF','RF','LF','RW','LW','RS','LS'},
    'SUB':{'SUB'},
    'RES':{'RES'}
}
position_dict
# Out:
# {'GOALKEEPER': {'GK'},
#  'DEFENDER': {'CB', 'LB', 'LCB', 'LWB', 'RB', 'RCB', 'RWB'},
#  'MIDFIELDER': {'CAM',
#   'CDM',
#   'CM',
#   'LAM',
#   'LCM',
#   'LDM',
#   'LM',
#   'RAM',
#   'RCM',
#   'RDM',
#   'RM'},
#  'FORWARD': {'CF', 'LF', 'LS', 'LW', 'RF', 'RS', 'RW', 'ST'},
#  'SUB': {'SUB'},
#  'RES': {'RES'}}

# %%
position = "CAM"
[key for key in position_dict if position in position_dict[key]].pop()
# Out:
# 'MIDFIELDER'

# %%
df3['Position2'] = [[key for key in position_dict if position in position_dict[key]].pop() for position in df3.Position]
df3.loc[:,['Position','Position2']]
# Out:
#       Position   Position2
# 0          CAM  MIDFIELDER
# 1          LDM  MIDFIELDER
# 2           RS     FORWARD
# 3          RCM  MIDFIELDER
# 4           LB    DEFENDER
# ...        ...         ...
# 16703      RES         RES
# 16704      RES         RES
# 16706      RES         RES
# 16707      RES         RES
# 16708      SUB         SUB
#
# [14398 rows x 2 columns]

# %% [markdown]
# ### D. 포지션별 능력치 비교

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall',
#        'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'Crossing', 'Finishing', 'HeadingAccuracy',
#        'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy',
#        'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed', 'Agility',
#        'Reactions', 'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength',
#        'LongShots', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
#        'Penalties', 'Composure', 'Marking', 'StandingTackle', 'SlidingTackle',
#        'GKDiving', 'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes',
#        'Best Position', 'Best Overall Rating', 'Release Clause',
#        'DefensiveAwareness'],
#       dtype='object')

# %% [markdown]
# `-` 포지션별로 "Dribbling", "ShotPower", "SlidingTackle" 능력의 평균을 구하라.
#
# - Dribbling의 평균능력치가 가장 좋은 포지션은 어디인가?
# - ShotPower의 평균능력치가 가장 좋은 포지션은 어디인가?
# - SlidingTackle의 평균능력치가 가장 좋은 포지션은 어디인가?
# - 세 능력치의 평균이 가장 좋은 포지션은?

# %%
df3.groupby("Position2")[["Dribbling","ShotPower","SlidingTackle"]].mean()
# Out:
#             Dribbling  ShotPower  SlidingTackle
# Position2
# DEFENDER    57.100000  55.638605      66.985116
# FORWARD     69.472997  71.105401      29.051394
# GOALKEEPER  14.996055  50.512821      14.353057
# MIDFIELDER  69.057130  67.587294      53.313985
# RES         53.150668  55.156928      42.362270
# SUB         58.582293  60.417540      45.524380

# %%
df3.groupby("Position2")[["Dribbling","ShotPower","SlidingTackle"]].mean().mean(axis=1)
# Out:
# Position2
# DEFENDER      59.907907
# FORWARD       56.543264
# GOALKEEPER    26.620644
# MIDFIELDER    63.319470
# RES           50.223289
# SUB           54.841405
# dtype: float64

# %% [markdown]
# ### F. 주급처리

# %%
df3['Wage'] = [eval(l.replace("€","").replace("K","*1000").replace("M","*1000000")) for l in df2.Wage]
df3
# Out:
#            ID             Name  Age  \
# 0      212198  Bruno Fernandes   26
# 1      209658      L. Goretzka   26
# 2      176580        L. Suárez   34
# 3      192985     K. De Bruyne   30
# 4      224334         M. Acuña   29
# ...       ...              ...  ...
# 16703  259718      F. Gebhardt   19
# 16704  251433          B. Voll   20
# 16706  262846         �. Dobre   20
# 16707  241317   21 Xue Qinghao   19
# 16708  259646        A. Shaikh   18
#
#                                                   Photo Nationality  \
# 0      https://cdn.sofifa.com/players/212/198/22_60.png    Portugal
# 1      https://cdn.sofifa.com/players/209/658/22_60.png     Germany
# 2      https://cdn.sofifa.com/players/176/580/22_60.png     Uruguay
# 3      https://cdn.sofifa.com/players/192/985/22_60.png     Belgium
# 4      https://cdn.sofifa.com/players/224/334/22_60.png   Argentina
# ...                                                 ...         ...
# 16703  https://cdn.sofifa.com/players/259/718/22_60.png     Germany
# 16704  https://cdn.sofifa.com/players/251/433/22_60.png     Germany
# 16706  https://cdn.sofifa.com/players/262/846/22_60.png     Romania
# 16707  https://cdn.sofifa.com/players/241/317/21_60.png    China PR
# 16708  https://cdn.sofifa.com/players/259/646/22_60.png       India
#
#                                       Flag  Overall  Potential  \
# 0      https://cdn.sofifa.com/flags/pt.png       88         89
# 1      https://cdn.sofifa.com/flags/de.png       87         88
# 2      https://cdn.sofifa.com/flags/uy.png       88         88
# 3      https://cdn.sofifa.com/flags/be.png       91         91
# 4      https://cdn.sofifa.com/flags/ar.png       84         84
# ...                                    ...      ...        ...
# 16703  https://cdn.sofifa.com/flags/de.png       52         66
# 16704  https://cdn.sofifa.com/flags/de.png       58         69
# 16706  https://cdn.sofifa.com/flags/ro.png       53         63
# 16707  https://cdn.sofifa.com/flags/cn.png       47         60
# 16708  https://cdn.sofifa.com/flags/in.png       47         67
#
#                         Club                                   Club Logo  ...  \
# 0          Manchester United      https://cdn.sofifa.com/teams/11/30.png  ...
# 1          FC Bayern München      https://cdn.sofifa.com/teams/21/30.png  ...
# 2         Atlético de Madrid     https://cdn.sofifa.com/teams/240/30.png  ...
# 3            Manchester City      https://cdn.sofifa.com/teams/10/30.png  ...
# 4                 Sevilla FC     https://cdn.sofifa.com/teams/481/30.png  ...
# ...                      ...                                         ...  ...
# 16703          FC Basel 1893     https://cdn.sofifa.com/teams/896/30.png  ...
# 16704     F.C. Hansa Rostock      https://cdn.sofifa.com/teams/27/30.png  ...
# 16706  FC Academica Clinceni  https://cdn.sofifa.com/teams/113391/30.png  ...
# 16707    Shanghai Shenhua FC  https://cdn.sofifa.com/teams/110955/30.png  ...
# 16708     ATK Mohun Bagan FC  https://cdn.sofifa.com/teams/113146/30.png  ...
#
#       GKHandling  GKKicking  GKPositioning GKReflexes  Best Position  \
# 0           14.0       15.0            8.0       14.0            CAM
# 1            8.0       15.0           11.0        9.0             CM
# 2           25.0       31.0           33.0       37.0             ST
# 3           13.0        5.0           10.0       13.0             CM
# 4           14.0       13.0           13.0       14.0             LB
# ...          ...        ...            ...        ...            ...
# 16703       45.0       47.0           52.0       57.0             GK
# 16704       60.0       56.0           55.0       61.0             GK
# 16706       52.0       53.0           48.0       58.0             GK
# 16707       48.0       45.0           38.0       52.0             GK
# 16708       41.0       39.0           45.0       49.0             GK
#
#        Best Overall Rating  Release Clause DefensiveAwareness    Postion2  \
# 0                     88.0         €206.9M               72.0  MIDFIELDER
# 1                     87.0         €160.4M               74.0  MIDFIELDER
# 2                     88.0          €91.2M               42.0     FORWARD
# 3                     91.0         €232.2M               68.0  MIDFIELDER
# 4                     84.0          €77.7M               80.0    DEFENDER
# ...                    ...             ...                ...         ...
# 16703                 52.0           €361K                6.0         RES
# 16704                 58.0           €656K                5.0         RES
# 16706                 53.0           €279K                5.0         RES
# 16707                 47.0           €223K               21.0         RES
# 16708                 47.0           €259K                7.0         SUB
#
#         Position2
# 0      MIDFIELDER
# 1      MIDFIELDER
# 2         FORWARD
# 3      MIDFIELDER
# 4        DEFENDER
# ...           ...
# 16703         RES
# 16704         RES
# 16706         RES
# 16707         RES
# 16708         SUB
#
# [14398 rows x 65 columns]

# %% [markdown]
# ### G. 주급분석

# %% [markdown]
# `-` 공격수 포지션의 선수들을 "SlidingTackle"에 따라 4개의 그룹으로 나누어라. "SlidingTackle"능력에 따른 주급차이가 있을까?

# %%
df_forward_only = df3[df3.Postion2 == "FORWARD"].copy()
df_forward_only
# Out:
#            ID                 Name  Age  \
# 2      176580            L. Suárez   34
# 29     158023             L. Messi   34
# 31     205632           L. Ocampos   26
# 33     188545       R. Lewandowski   32
# 34     209331             M. Salah   29
# ...       ...                  ...  ...
# 14327  257495  L. Lawrie-Lattanzio   19
# 14335  261948           A. Parsons   21
# 14337  240208           R. Bennett   30
# 14550  259626             C. Offor   21
# 14553  257060        L. Jastremski   20
#
#                                                   Photo Nationality  \
# 2      https://cdn.sofifa.com/players/176/580/22_60.png     Uruguay
# 29     https://cdn.sofifa.com/players/158/023/22_60.png   Argentina
# 31     https://cdn.sofifa.com/players/205/632/22_60.png   Argentina
# 33     https://cdn.sofifa.com/players/188/545/22_60.png      Poland
# 34     https://cdn.sofifa.com/players/209/331/22_60.png       Egypt
# ...                                                 ...         ...
# 14327  https://cdn.sofifa.com/players/257/495/22_60.png   Australia
# 14335  https://cdn.sofifa.com/players/261/948/22_60.png   Australia
# 14337  https://cdn.sofifa.com/players/240/208/22_60.png     England
# 14550  https://cdn.sofifa.com/players/259/626/22_60.png     Nigeria
# 14553  https://cdn.sofifa.com/players/257/060/22_60.png     Germany
#
#                                           Flag  Overall  Potential  \
# 2          https://cdn.sofifa.com/flags/uy.png       88         88
# 29         https://cdn.sofifa.com/flags/ar.png       93         93
# 31         https://cdn.sofifa.com/flags/ar.png       83         83
# 33         https://cdn.sofifa.com/flags/pl.png       92         92
# 34         https://cdn.sofifa.com/flags/eg.png       89         89
# ...                                        ...      ...        ...
# 14327      https://cdn.sofifa.com/flags/au.png       55         70
# 14335      https://cdn.sofifa.com/flags/au.png       58         72
# 14337  https://cdn.sofifa.com/flags/gb-eng.png       60         60
# 14550      https://cdn.sofifa.com/flags/ng.png       59         73
# 14553      https://cdn.sofifa.com/flags/de.png       61         75
#
#                              Club                                   Club Logo  \
# 2              Atlético de Madrid     https://cdn.sofifa.com/teams/240/30.png
# 29            Paris Saint-Germain      https://cdn.sofifa.com/teams/73/30.png
# 31                     Sevilla FC     https://cdn.sofifa.com/teams/481/30.png
# 33              FC Bayern München      https://cdn.sofifa.com/teams/21/30.png
# 34                      Liverpool       https://cdn.sofifa.com/teams/9/30.png
# ...                           ...                                         ...
# 14327           Melbourne Victory  https://cdn.sofifa.com/teams/111397/30.png
# 14335               Brisbane Roar  https://cdn.sofifa.com/teams/111395/30.png
# 14337               Sutton United  https://cdn.sofifa.com/teams/110799/30.png
# 14550  Chicago Fire Football Club     https://cdn.sofifa.com/teams/693/30.png
# 14553               Viktoria Köln  https://cdn.sofifa.com/teams/110645/30.png
#
#        ... GKHandling  GKKicking  GKPositioning GKReflexes  Best Position  \
# 2      ...       25.0       31.0           33.0       37.0             ST
# 29     ...       11.0       15.0           14.0        8.0             RW
# 31     ...        8.0       15.0           12.0        7.0             LW
# 33     ...        6.0       12.0            8.0       10.0             ST
# 34     ...       14.0        9.0           11.0       14.0             RW
# ...    ...        ...        ...            ...        ...            ...
# 14327  ...       11.0       13.0           10.0        7.0             ST
# 14335  ...       13.0       13.0           11.0       10.0             RW
# 14337  ...       11.0       10.0            6.0        9.0             ST
# 14550  ...       10.0        6.0           11.0       14.0             ST
# 14553  ...        6.0        8.0           10.0        9.0             ST
#
#        Best Overall Rating  Release Clause DefensiveAwareness Postion2  \
# 2                     88.0          €91.2M               42.0  FORWARD
# 29                    93.0         €144.3M               20.0  FORWARD
# 31                    83.0            €83M               58.0  FORWARD
# 33                    92.0         €197.2M               35.0  FORWARD
# 34                    89.0         €186.9M               38.0  FORWARD
# ...                    ...             ...                ...      ...
# 14327                 57.0           €563K               19.0  FORWARD
# 14335                 58.0           €938K               22.0  FORWARD
# 14337                 60.0           €420K               21.0  FORWARD
# 14550                 61.0           €1.1M               15.0  FORWARD
# 14553                 63.0           €1.7M               10.0  FORWARD
#
#       Position2
# 2       FORWARD
# 29      FORWARD
# 31      FORWARD
# 33      FORWARD
# 34      FORWARD
# ...         ...
# 14327   FORWARD
# 14335   FORWARD
# 14337   FORWARD
# 14550   FORWARD
# 14553   FORWARD
#
# [1148 rows x 65 columns]

# %%
df_forward_only.assign(
    SlidingTackle_qcut = pd.qcut(df_forward_only.SlidingTackle,4)
).groupby("SlidingTackle_qcut")["Wage"].mean()
# Out:
# /tmp/ipykernel_665326/3495858949.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   ).groupby("SlidingTackle_qcut")["Wage"].mean()
# SlidingTackle_qcut
# (9.999, 20.0]    13129.206349
# (20.0, 26.0]     15543.962264
# (26.0, 36.0]     19396.523179
# (36.0, 74.0]     18600.751880
# Name: Wage, dtype: float64

# %% [markdown]
# `-` 공격수 포지션의 선수들을 "ShotPower"의 능력에 따라 4개의 그룹으로 나누어라. "ShotPower"능력에 따른 주급차이가 있을까?

# %%
df_forward_only.assign(
    ShotPower_qcut = pd.qcut(df_forward_only.ShotPower,4)
).groupby("ShotPower_qcut")["Wage"].mean()
# Out:
# /tmp/ipykernel_665326/769531155.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   ).groupby("ShotPower_qcut")["Wage"].mean()
# ShotPower_qcut
# (39.999, 66.0]     3736.569579
# (66.0, 71.0]       6737.321429
# (71.0, 77.0]      14354.560261
# (77.0, 94.0]      46081.349206
# Name: Wage, dtype: float64

# %% [markdown]
# ## 2. 평균처리

# %% [markdown]
# `-` numpy

# %%
X = np.array([[1,2,3],[1,2,4]])
X
# Out:
# array([[1, 2, 3],
#        [1, 2, 4]])

# %%
X.sum()
# Out:
# np.int64(13)

# %%
X.sum(axis=0)
# Out:
# array([2, 4, 7])

# %%
X.sum(axis=1)
# Out:
# array([6, 7])

# %% [markdown]
# `-` df

# %%
X = pd.DataFrame(X)
X
# Out:
#    0  1  2
# 0  1  2  3
# 1  1  2  4

# %%
X.sum()
# Out:
# 0    2
# 1    4
# 2    7
# dtype: int64

# %%
X.sum(axis=0)
# Out:
# 0    2
# 1    4
# 2    7
# dtype: int64

# %%
X.sum(axis=1)
# Out:
# 0    6
# 1    7
# dtype: int64
