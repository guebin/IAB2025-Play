# %% [raw]
# ---
# title: "12wk-1: [DataFrame] -- Pandas 문법 (2) // 숙제"
# author: "최규빈"
# date: "05/19/2025"
# draft: false
# ---

# %%
# {{<video https://youtu.be/playlist?list=PLQqh36zP38-yBnQwNwr2p9OAuFHfXUfVo&si=-dcYsV4g_u4qARlG>}}

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Pandas 행과열의선택

# %% [markdown]
# ### A. df 만들기

# %%
dct = {'date': ['12/30','12/31','01/01','01/02','01/03'], 'X1': [65,95,65,55,80], 'X2': [55,100,90,80,30], 'X3': [50,50,60,75,30], 'X4': [40,80,30,80,100]}
df = pd.DataFrame(dct)
df
# Out:
#     date  X1   X2  X3   X4
# 0  12/30  65   55  50   40
# 1  12/31  95  100  50   80
# 2  01/01  65   90  60   30
# 3  01/02  55   80  75   80
# 4  01/03  80   30  30  100

# %% [markdown]
# ### B. 열의 선택

# %% [markdown]
# `-` 방법1 -- `df.`

# %%
# df.X1

# %% [markdown]
# `-` 방법2 -- `df[]`

# %%
# df['X1'] # str 
# df[['X1']] # [str]
# df[['X1','X3']] # [str,str]

# %% [markdown]
# `-` 방법3 -- `df.iloc`

# %%
# df.iloc[:,0] # int
# df.iloc[:,-2:] # int:int - 슬라이싱
# df.iloc[:,1::2] # int:int - 스트라이딩
# df.iloc[:,[0]] # [int]
# df.iloc[:,[0,1]] # [int,int]
# df.iloc[:,[True,True,False,False]] # bool의 list 
# df.iloc[:,range(2)] # range

# %% [markdown]
# `-` 방법4 -- `df.loc`

# %%
# df.loc[:,'X1'] # str
# df.loc[:,'X1':'X3'] # 'str':'str' -- 칼럼이름으로 슬라이싱 **
# df.loc[:,'X1'::2] # 'str':'str' -- 칼럼이름으로 스트라이딩 ** 
# df.loc[:,['X1']] # [str]
# df.loc[:,['X1','X4']] # [str,str]
# df.loc[:,[True,False,False,True,True]] # bool의 list

# %% [markdown]
# **수업때 헤맨 내용 재 설명**

# %% [markdown]
# 자료형이 `pandas.core.series.Series` 인 경우와 `pandas.core.frame.DataFrame` 인 경우는 사용가능한 메소드가 다른 경우도 있으므로 조심해야함.

# %%
df = pd.read_csv("https://raw.githubusercontent.com/guebin/IAB2025-Play/refs/heads/main/content/titanic.csv")[:5]
df
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# 아래의 2개는 비슷해보이지만 약간 다를수 있음

# %%
df['Survived']
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Survived, dtype: int64

# %%
df[['Survived']]
# Out:
#    Survived
# 0         0
# 1         1
# 2         1
# 3         1
# 4         0

# %% [markdown]
# `# 예시1` -- 비슷하게 동작하는 경우

# %%
df['Survived'].mean()
# Out:
# np.float64(0.6)

# %%
df[['Survived']].mean()
# Out:
# Survived    0.6
# dtype: float64

# %% [markdown]
# `#`

# %% [markdown]
# `# 예시2` -- 비슷하게 동작하지 않는 경우

# %%
df[['Survived']].to_list()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_557209/2135151720.py in ?()
# ----> 1 df[['Survived']].to_list()
#
# ~/anaconda3/envs/iab2025/lib/python3.13/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'to_list'

# %%
df['Survived'].to_list()
# Out:
# [0, 1, 1, 1, 0]

# %% [markdown]
# `#`

# %% [markdown]
# ### B. 행의 선택

# %%
dct = {'date': ['12/30','12/31','01/01','01/02','01/03'], 'X1': [65,95,65,55,80], 'X2': [55,100,90,80,30], 'X3': [50,50,60,75,30], 'X4': [40,80,30,80,100]}
df = pd.DataFrame(dct)
df
# Out:
#     date  X1   X2  X3   X4
# 0  12/30  65   55  50   40
# 1  12/31  95  100  50   80
# 2  01/01  65   90  60   30
# 3  01/02  55   80  75   80
# 4  01/03  80   30  30  100

# %% [markdown]
# `-` 방법1: `df[]` + int:int, str:str, \[bool,bool\],
# pd.Series(\[bool,bool\]) – $(\star\star\star\star\star)$

# %%
# df[:2] # int:int -- 슬라이싱 // df.iloc[:2,:], df.iloc[:2] 와 같음
# df[::2] # int:int -- 스트라이딩 
# ts['12/30':'01/02'] # str:str -- 슬라이싱
# ts['12/31'::2] # str:str -- 스트라이딩
# df[['12' in date for date in df.date]] # [bool,bool]
# df[df.X1 < 70] # pd.Series([bool,bool])

# %% [markdown]
# `-` 방법2: `df.iloc[]`, `df.iloc[,:]` + int, int:int, \[int,int\],
# \[bool,bool\], range

# %%
# df.iloc[0] # int 
# df.iloc[-2:] # int:int -- 슬라이싱
# df.iloc[1::2] # int:int -- 스트라이딩
# df.iloc[[0]] # [int]
# df.iloc[[0,1]] # [int,int]
# df.iloc[['12' in date for date in df.date]] # [bool,bool]
# df.iloc[range(2)] # range

# %%
# df.iloc[0,:] # int 
# df.iloc[-2:,:] # int:int -- 슬라이싱
# df.iloc[1::2,:] # int:int -- 스트라이딩
# df.iloc[[0],:] # [int]
# df.iloc[[0,1],:] # [int,int]
# df.iloc[['12' in date for date in df.date],:] # [bool,bool]
# df.iloc[range(2),:] # range

# %% [markdown]
# `-` 방법3: `df.loc[]`, `df.loc[,:]` + int, str, int:int, str:str,
# \[int,int\], \[str,str\], \[bool,bool\], pd.Series(\[bool,bool\])

# %%
# df.loc[0] # int 
# ts.loc['12/30'] # str 
# df.loc[:2] # int:int 
# ts.loc[:'01/02'] # str:str 
# df.loc[[0,1]] # [int,int]
# ts.loc[['12/30','01/01']] # [str,str]
# df.loc[['12' in date for date in df.date]] # [bool,bool]
# df.loc[df.X1>70] # pd.Series([bool,bool])

# %% [markdown]
# ### C. 제 스타일

# %% [markdown]
# `-` **가장 안전한 코드**

# %%
# df.loc[:,:]

# %% [markdown]
# `-` 상황1: 하나의 col을 뽑으려 할때 좋은 코드

# %%
# df.X1 # 최애 
# df['X1'] # 차애 
# df[['X1']] # 차애

# %% [markdown]
# `-` 상황2: row 슬라이싱을 할때 좋은 코드 $(\star\star\star)$

# %%
# df[:5] # 최애 
# ts[:'01/02'] # 시계열인 경우

# %% [markdown]
# `-` 상황3: 조건에 맞는 row를 뽑을때 좋은 코드

# %%
# df[df.X1<60] # 최애
# df.loc[['12' in date for date in df.date]] # 차애

# %% [markdown]
# `-` 상황4: 하나의 row를 뽑으려 할때 좋은 코드

# %%
# df.iloc[0] # 최애 
# df.loc[0] # 차애

# %% [markdown]
# `-` 상황5: (row,col)을 뽑으려 할때 좋은 코드

# %%
# 최애: pd.Series를 뽑고 -> 인덱스로접근
# df.X1[0]
# df['X1'][0]

# 차애: iloc, loc 으로 한번에 뽑기
# df.iloc[0,0]
# df.loc[0,'X1']

# %% [markdown]
# ***위의 상황이외에는 `df.loc[:,:]`를 사용하는것이 유리하다***
#
# `-` 상황6: column 슬라이싱을 할때

# %%
# df.loc[:,'X1':'X3'] # 끝점포함

# %% [markdown]
# `-` 상황7: row + column 슬라이싱을 하는 가장 좋은 코드

# %%
# df.loc[::2,'X1':'X2']

# %% [markdown]
# `-` 상황8: 조건에 맞는 col을 뽑기에 가장 좋은 코드

# %%
# df.loc[:,[len(colname)>2 for colname in df.columns]]

# %% [markdown]
# `-` 상황9: 조건에 맞는 row, col을 뽑기에 가장 좋은 코드

# %%
# df.loc[df.X1>70,[len(colname)>2 for colname in df.columns]]

# %% [markdown]
# ### D. 제 스타일 X

# %% [markdown]
# `-` 제가 안쓰는 코드1

# %%
df[:1]
# Out:
#     date  X1  X2  X3  X4
# 0  12/30  65  55  50  40

# %% [markdown]
# 이러면 내 입장에서는 마치 아래가 동작할 것 같잖아..

# %%
df[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/iab2025/lib/python3.13/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[113], line 1
# ----> 1 df[0]
#
# File ~/anaconda3/envs/iab2025/lib/python3.13/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/anaconda3/envs/iab2025/lib/python3.13/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 0

# %% [markdown]
# `-` 제가 안쓰는 코드2: bool의 list를 사용할때 iloc은 가급적 쓰지마세요

# %%
df.iloc[list(df['X1']<80),:]
# Out:
#     date  X1  X2  X3  X4
# 0  12/30  65  55  50  40
# 2  01/01  65  90  60  30
# 3  01/02  55  80  75  80

# %% [markdown]
# 이러면 마치 아래도 동작할 것 같잖아..

# %%
df.iloc[df['X1']<80,:]
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[115], line 1
# ----> 1 df.iloc[df['X1']<80,:]
#
# File ~/anaconda3/envs/iab2025/lib/python3.13/site-packages/pandas/core/indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File ~/anaconda3/envs/iab2025/lib/python3.13/site-packages/pandas/core/indexing.py:1690, in _iLocIndexer._getitem_tuple(self, tup)
#    1689 def _getitem_tuple(self, tup: tuple):
# -> 1690     tup = self._validate_tuple_indexer(tup)
#    1691     with suppress(IndexingError):
#    1692         return self._getitem_lowerdim(tup)
#
# File ~/anaconda3/envs/iab2025/lib/python3.13/site-packages/pandas/core/indexing.py:966, in _LocationIndexer._validate_tuple_indexer(self, key)
#     964 for i, k in enumerate(key):
#     965     try:
# --> 966         self._validate_key(k, i)
#     967     except ValueError as err:
#     968         raise ValueError(
#     969             "Location based indexing can only have "
#     970             f"[{self._valid_types}] types"
#     971         ) from err
#
# File ~/anaconda3/envs/iab2025/lib/python3.13/site-packages/pandas/core/indexing.py:1578, in _iLocIndexer._validate_key(self, key, axis)
#    1576 if hasattr(key, "index") and isinstance(key.index, Index):
#    1577     if key.index.inferred_type == "integer":
# -> 1578         raise NotImplementedError(
#    1579             "iLocation based boolean "
#    1580             "indexing on an integer type "
#    1581             "is not available"
#    1582         )
#    1583     raise ValueError(
#    1584         "iLocation based boolean indexing cannot use "
#    1585         "an indexable as a mask"
#    1586     )
#    1587 return
#
# NotImplementedError: iLocation based boolean indexing on an integer type is not available

# %% [markdown]
# ### E. 필터링 -- numpy랑 비슷

# %%
df
# Out:
#     date  X1   X2  X3   X4
# 0  12/30  65   55  50   40
# 1  12/31  95  100  50   80
# 2  01/01  65   90  60   30
# 3  01/02  55   80  75   80
# 4  01/03  80   30  30  100

# %%
df.X1 + df.X2 > 150
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# 4    False
# dtype: bool

# %%
df[df.X1 + df.X2 > 150]
# Out:
#     date  X1   X2  X3  X4
# 1  12/31  95  100  50  80
# 2  01/01  65   90  60  30

# %% [markdown]
# ## 2. FIFA데이터

# %% [markdown]
# ### A. Data

# %% [markdown]
# `-` 데이터 load

# %%
df = pd.read_csv('https://raw.githubusercontent.com/guebin/DV2022/master/posts/FIFA23_official_data.csv')
df.head()
# Out:
#        ID             Name  Age  \
# 0  209658      L. Goretzka   27
# 1  212198  Bruno Fernandes   27
# 2  224334         M. Acuña   30
# 3  192985     K. De Bruyne   31
# 4  224232       N. Barella   25
#
#                                               Photo Nationality  \
# 0  https://cdn.sofifa.net/players/209/658/23_60.png     Germany
# 1  https://cdn.sofifa.net/players/212/198/23_60.png    Portugal
# 2  https://cdn.sofifa.net/players/224/334/23_60.png   Argentina
# 3  https://cdn.sofifa.net/players/192/985/23_60.png     Belgium
# 4  https://cdn.sofifa.net/players/224/232/23_60.png       Italy
#
#                                   Flag  Overall  Potential               Club  \
# 0  https://cdn.sofifa.net/flags/de.png       87         88  FC Bayern München
# 1  https://cdn.sofifa.net/flags/pt.png       86         87  Manchester United
# 2  https://cdn.sofifa.net/flags/ar.png       85         85         Sevilla FC
# 3  https://cdn.sofifa.net/flags/be.png       91         91    Manchester City
# 4  https://cdn.sofifa.net/flags/it.png       86         89              Inter
#
#                                  Club Logo  ... Real Face  \
# 0   https://cdn.sofifa.net/teams/21/30.png  ...       Yes
# 1   https://cdn.sofifa.net/teams/11/30.png  ...       Yes
# 2  https://cdn.sofifa.net/teams/481/30.png  ...        No
# 3   https://cdn.sofifa.net/teams/10/30.png  ...       Yes
# 4   https://cdn.sofifa.net/teams/44/30.png  ...       Yes
#
#                       Position        Joined Loaned From  \
# 0  <span class="pos pos28">SUB   Jul 1, 2018         NaN
# 1  <span class="pos pos15">LCM  Jan 30, 2020         NaN
# 2    <span class="pos pos7">LB  Sep 14, 2020         NaN
# 3  <span class="pos pos13">RCM  Aug 30, 2015         NaN
# 4  <span class="pos pos13">RCM   Sep 1, 2020         NaN
#
#    Contract Valid Until  Height  Weight Release Clause Kit Number  \
# 0                  2026   189cm    82kg          €157M        8.0
# 1                  2026   179cm    69kg          €155M        8.0
# 2                  2024   172cm    69kg         €97.7M       19.0
# 3                  2025   181cm    70kg        €198.9M       17.0
# 4                  2026   172cm    68kg        €154.4M       23.0
#
#   Best Overall Rating
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#
# [5 rows x 29 columns]

# %% [markdown]
# ### B. `df.T`

# %% [markdown]
# `-` `df.T`를 이용하여 데이터를 살피면 편리함

# %%
df.T.iloc[:,:2]
# Out:
#                                                                          0  \
# ID                                                                  209658
# Name                                                           L. Goretzka
# Age                                                                     27
# Photo                     https://cdn.sofifa.net/players/209/658/23_60.png
# Nationality                                                        Germany
# Flag                                   https://cdn.sofifa.net/flags/de.png
# Overall                                                                 87
# Potential                                                               88
# Club                                                     FC Bayern München
# Club Logo                           https://cdn.sofifa.net/teams/21/30.png
# Value                                                                 €91M
# Wage                                                                 €115K
# Special                                                               2312
# Preferred Foot                                                       Right
# International Reputation                                               4.0
# Weak Foot                                                              4.0
# Skill Moves                                                            3.0
# Work Rate                                                     High/ Medium
# Body Type                                                           Unique
# Real Face                                                              Yes
# Position                                       <span class="pos pos28">SUB
# Joined                                                         Jul 1, 2018
# Loaned From                                                            NaN
# Contract Valid Until                                                  2026
# Height                                                               189cm
# Weight                                                                82kg
# Release Clause                                                       €157M
# Kit Number                                                             8.0
# Best Overall Rating                                                    NaN
#
#                                                                          1
# ID                                                                  212198
# Name                                                       Bruno Fernandes
# Age                                                                     27
# Photo                     https://cdn.sofifa.net/players/212/198/23_60.png
# Nationality                                                       Portugal
# Flag                                   https://cdn.sofifa.net/flags/pt.png
# Overall                                                                 86
# Potential                                                               87
# Club                                                     Manchester United
# Club Logo                           https://cdn.sofifa.net/teams/11/30.png
# Value                                                               €78.5M
# Wage                                                                 €190K
# Special                                                               2305
# Preferred Foot                                                       Right
# International Reputation                                               3.0
# Weak Foot                                                              3.0
# Skill Moves                                                            4.0
# Work Rate                                                       High/ High
# Body Type                                                           Unique
# Real Face                                                              Yes
# Position                                       <span class="pos pos15">LCM
# Joined                                                        Jan 30, 2020
# Loaned From                                                            NaN
# Contract Valid Until                                                  2026
# Height                                                               179cm
# Weight                                                                69kg
# Release Clause                                                       €155M
# Kit Number                                                             8.0
# Best Overall Rating                                                    NaN

# %% [markdown]
# `-` 출력옵션 조정

# %%
pd.options.display.max_rows = 12
display(df.T.iloc[:,:2])
pd.reset_option("display.max_rows")
# Out:
#                                                                     0  \
# ID                                                             209658
# Name                                                      L. Goretzka
# Age                                                                27
# Photo                https://cdn.sofifa.net/players/209/658/23_60.png
# Nationality                                                   Germany
# ...                                                               ...
# Height                                                          189cm
# Weight                                                           82kg
# Release Clause                                                  €157M
# Kit Number                                                        8.0
# Best Overall Rating                                               NaN
#
#                                                                     1
# ID                                                             212198
# Name                                                  Bruno Fernandes
# Age                                                                27
# Photo                https://cdn.sofifa.net/players/212/198/23_60.png
# Nationality                                                  Portugal
# ...                                                               ...
# Height                                                          179cm
# Weight                                                           69kg
# Release Clause                                                  €155M
# Kit Number                                                        8.0
# Best Overall Rating                                               NaN
#
# [29 rows x 2 columns]

# %% [markdown]
# - 이 예제에서는 줄이는 옵션을 사용했지만 보통은 늘려서 사용함

# %% [markdown]
# ### C. `df.dtypes`, `s.dtype`, `df.select_dtypes()`

# %% [markdown]
# `-` `df.dtypes`

# %%
df.dtypes
# Out:
# ID                            int64
# Name                         object
# Age                           int64
# Photo                        object
# Nationality                  object
# Flag                         object
# Overall                       int64
# Potential                     int64
# Club                         object
# Club Logo                    object
# Value                        object
# Wage                         object
# Special                       int64
# Preferred Foot               object
# International Reputation    float64
# Weak Foot                   float64
# Skill Moves                 float64
# Work Rate                    object
# Body Type                    object
# Real Face                    object
# Position                     object
# Joined                       object
# Loaned From                  object
# Contract Valid Until         object
# Height                       object
# Weight                       object
# Release Clause               object
# Kit Number                  float64
# Best Overall Rating          object
# dtype: object

# %% [markdown]
# `-` `s.dtype`

# %%
df.Name.dtype
# Out:
# dtype('O')

# %% [markdown]
# `-` `==`를 이용한 자료형 체크

# %%
df.Name.dtype == object
df.Name.dtype == np.object_
# Out:
# True

# %%
df.Age.dtype == int
df.Age.dtype == np.int64
# Out:
# True

# %%
df['International Reputation'].dtype == float
df['International Reputation'].dtype == np.float64
# Out:
# True

# %% [markdown]
# `# 예제1`: `df`에서 `int` 자료형만 출력

# %% [markdown]
# `-` (풀이1)

# %%
df.loc[:,[l == int for l in df.dtypes]]
df.loc[:,[l == np.int64 for l in df.dtypes]]
# Out:
#            ID  Age  Overall  Potential  Special
# 0      209658   27       87         88     2312
# 1      212198   27       86         87     2305
# 2      224334   30       85         85     2303
# 3      192985   31       91         91     2303
# 4      224232   25       86         89     2296
# ...       ...  ...      ...        ...      ...
# 17655  269526   19       48         61      762
# 17656  267946   17       48         64      761
# 17657  270567   25       51         56      759
# 17658  256624   18       50         65      758
# 17659  256376   20       50         61      749
#
# [17660 rows x 5 columns]

# %% [markdown]
# `-` (풀이2)

# %%
df.select_dtypes(int)
df.select_dtypes(np.int64)
df.select_dtypes([int])
df.select_dtypes([np.int64])
# Out:
#            ID  Age  Overall  Potential  Special
# 0      209658   27       87         88     2312
# 1      212198   27       86         87     2305
# 2      224334   30       85         85     2303
# 3      192985   31       91         91     2303
# 4      224232   25       86         89     2296
# ...       ...  ...      ...        ...      ...
# 17655  269526   19       48         61      762
# 17656  267946   17       48         64      761
# 17657  270567   25       51         56      759
# 17658  256624   18       50         65      758
# 17659  256376   20       50         61      749
#
# [17660 rows x 5 columns]

# %% [markdown]
# `#`

# %% [markdown]
# `# 예제2`: `df`에서 `int`, `float` 자료형만 출력 -- `select_dtypes()` 이용

# %%
df.select_dtypes([int,float])
df.select_dtypes([np.int64,np.float64])
df.select_dtypes('number')
df.select_dtypes(['number'])
# Out:
#            ID  Age  Overall  Potential  Special  International Reputation  \
# 0      209658   27       87         88     2312                       4.0
# 1      212198   27       86         87     2305                       3.0
# 2      224334   30       85         85     2303                       2.0
# 3      192985   31       91         91     2303                       4.0
# 4      224232   25       86         89     2296                       3.0
# ...       ...  ...      ...        ...      ...                       ...
# 17655  269526   19       48         61      762                       1.0
# 17656  267946   17       48         64      761                       1.0
# 17657  270567   25       51         56      759                       1.0
# 17658  256624   18       50         65      758                       1.0
# 17659  256376   20       50         61      749                       1.0
#
#        Weak Foot  Skill Moves  Kit Number
# 0            4.0          3.0         8.0
# 1            3.0          4.0         8.0
# 2            3.0          3.0        19.0
# 3            5.0          4.0        17.0
# 4            3.0          3.0        23.0
# ...          ...          ...         ...
# 17655        3.0          1.0        35.0
# 17656        2.0          1.0        21.0
# 17657        2.0          1.0        12.0
# 17658        2.0          1.0        40.0
# 17659        2.0          1.0        30.0
#
# [17660 rows x 9 columns]

# %% [markdown]
# `#`

# %% [markdown]
# `# 예제3`: `df`에서 `object` 자료형만 출력 -- `select_dtypes()` 이용

# %%
df.select_dtypes(object)
df.select_dtypes([object])
# Out:
#                   Name                                             Photo  \
# 0          L. Goretzka  https://cdn.sofifa.net/players/209/658/23_60.png
# 1      Bruno Fernandes  https://cdn.sofifa.net/players/212/198/23_60.png
# 2             M. Acuña  https://cdn.sofifa.net/players/224/334/23_60.png
# 3         K. De Bruyne  https://cdn.sofifa.net/players/192/985/23_60.png
# 4           N. Barella  https://cdn.sofifa.net/players/224/232/23_60.png
# ...                ...                                               ...
# 17655    Deng Xiongtao  https://cdn.sofifa.net/players/269/526/23_60.png
# 17656   22 Lim Jun Sub  https://cdn.sofifa.net/players/267/946/22_60.png
# 17657         A. Demir  https://cdn.sofifa.net/players/270/567/23_60.png
# 17658     21 S. Czajor  https://cdn.sofifa.net/players/256/624/21_60.png
# 17659  21 F. Jakobsson  https://cdn.sofifa.net/players/256/376/21_60.png
#
#           Nationality                                 Flag               Club  \
# 0             Germany  https://cdn.sofifa.net/flags/de.png  FC Bayern München
# 1            Portugal  https://cdn.sofifa.net/flags/pt.png  Manchester United
# 2           Argentina  https://cdn.sofifa.net/flags/ar.png         Sevilla FC
# 3             Belgium  https://cdn.sofifa.net/flags/be.png    Manchester City
# 4               Italy  https://cdn.sofifa.net/flags/it.png              Inter
# ...               ...                                  ...                ...
# 17655        China PR  https://cdn.sofifa.net/flags/cn.png      Meizhou Hakka
# 17656  Korea Republic  https://cdn.sofifa.net/flags/kr.png     Jeju United FC
# 17657          Turkey  https://cdn.sofifa.net/flags/tr.png       Ümraniyespor
# 17658          Poland  https://cdn.sofifa.net/flags/pl.png     Fleetwood Town
# 17659          Sweden  https://cdn.sofifa.net/flags/se.png     IFK Norrköping
#
#                                         Club Logo    Value   Wage  \
# 0          https://cdn.sofifa.net/teams/21/30.png     €91M  €115K
# 1          https://cdn.sofifa.net/teams/11/30.png   €78.5M  €190K
# 2         https://cdn.sofifa.net/teams/481/30.png   €46.5M   €46K
# 3          https://cdn.sofifa.net/teams/10/30.png  €107.5M  €350K
# 4          https://cdn.sofifa.net/teams/44/30.png   €89.5M  €110K
# ...                                           ...      ...    ...
# 17655  https://cdn.sofifa.net/teams/114628/30.png    €100K   €500
# 17656    https://cdn.sofifa.net/teams/1478/30.png    €100K   €500
# 17657  https://cdn.sofifa.net/teams/113796/30.png     €70K    €2K
# 17658  https://cdn.sofifa.net/teams/112260/30.png     €90K   €500
# 17659     https://cdn.sofifa.net/teams/702/30.png     €90K   €500
#
#       Preferred Foot       Work Rate         Body Type Real Face  \
# 0              Right    High/ Medium            Unique       Yes
# 1              Right      High/ High            Unique       Yes
# 2               Left      High/ High  Stocky (170-185)        No
# 3              Right      High/ High            Unique       Yes
# 4              Right      High/ High     Normal (170-)       Yes
# ...              ...             ...               ...       ...
# 17655          Right  Medium/ Medium     Normal (185+)        No
# 17656          Right  Medium/ Medium       Lean (185+)        No
# 17657          Right  Medium/ Medium       Lean (185+)        No
# 17658          Right  Medium/ Medium     Normal (185+)        No
# 17659           Left  Medium/ Medium     Normal (185+)        No
#
#                           Position        Joined Loaned From  \
# 0      <span class="pos pos28">SUB   Jul 1, 2018         NaN
# 1      <span class="pos pos15">LCM  Jan 30, 2020         NaN
# 2        <span class="pos pos7">LB  Sep 14, 2020         NaN
# 3      <span class="pos pos13">RCM  Aug 30, 2015         NaN
# 4      <span class="pos pos13">RCM   Sep 1, 2020         NaN
# ...                            ...           ...         ...
# 17655  <span class="pos pos29">RES  Apr 11, 2022         NaN
# 17656  <span class="pos pos29">RES   Jan 1, 2022         NaN
# 17657  <span class="pos pos29">RES   Jun 6, 2021         NaN
# 17658  <span class="pos pos29">RES   Jan 1, 2020         NaN
# 17659  <span class="pos pos29">RES   Jan 8, 2020         NaN
#
#       Contract Valid Until Height Weight Release Clause Best Overall Rating
# 0                     2026  189cm   82kg          €157M                 NaN
# 1                     2026  179cm   69kg          €155M                 NaN
# 2                     2024  172cm   69kg         €97.7M                 NaN
# 3                     2025  181cm   70kg        €198.9M                 NaN
# 4                     2026  172cm   68kg        €154.4M                 NaN
# ...                    ...    ...    ...            ...                 ...
# 17655                 2027  190cm   78kg          €218K                 NaN
# 17656                 2026  195cm   84kg          €188K                 NaN
# 17657                 2023  190cm   82kg          €142K                 NaN
# 17658                 2021  187cm   79kg          €214K                 NaN
# 17659                 2021  186cm   78kg          €131K                 NaN
#
# [17660 rows x 20 columns]

# %% [markdown]
# `#`

# %% [markdown]
# ### D. `df.sort_values()`

# %% [markdown]
# `-` 예시1: 나이가 어린 순서대로 정렬

# %%
df.sort_values(by='Age')
# Out:
#            ID              Name  Age  \
# 17636  263636     22 D. Oncescu   15
# 13536  270867         A. Mazilu   16
# 17544  269196      22 M. Anchor   16
# 13509  271182         M. Moraru   16
# 15654  269024  22 Zeng Yaozhang   16
# ...       ...               ...  ...
# 16036  216692        S. Torrico   42
# 3143   153260         21 Hilton   42
# 17257     645   17 D. Andersson   43
# 15375    1179         G. Buffon   44
# 15272  254704       22 K. Miura   54
#
#                                                   Photo Nationality  \
# 17636  https://cdn.sofifa.net/players/263/636/22_60.png     Romania
# 13536  https://cdn.sofifa.net/players/270/867/23_60.png     Romania
# 17544  https://cdn.sofifa.net/players/269/196/22_60.png      Canada
# 13509  https://cdn.sofifa.net/players/271/182/23_60.png     Romania
# 15654  https://cdn.sofifa.net/players/269/024/22_60.png    China PR
# ...                                                 ...         ...
# 16036  https://cdn.sofifa.net/players/216/692/23_60.png   Argentina
# 3143   https://cdn.sofifa.net/players/153/260/21_60.png      Brazil
# 17257  https://cdn.sofifa.net/players/000/645/17_60.png      Sweden
# 15375  https://cdn.sofifa.net/players/001/179/23_60.png       Italy
# 15272  https://cdn.sofifa.net/players/254/704/22_60.png       Japan
#
#                                       Flag  Overall  Potential  \
# 17636  https://cdn.sofifa.net/flags/ro.png       50         72
# 13536  https://cdn.sofifa.net/flags/ro.png       55         75
# 17544  https://cdn.sofifa.net/flags/ca.png       47         70
# 13509  https://cdn.sofifa.net/flags/ro.png       50         72
# 15654  https://cdn.sofifa.net/flags/cn.png       46         56
# ...                                    ...      ...        ...
# 16036  https://cdn.sofifa.net/flags/ar.png       72         72
# 3143   https://cdn.sofifa.net/flags/br.png       75         75
# 17257  https://cdn.sofifa.net/flags/se.png       57         57
# 15375  https://cdn.sofifa.net/flags/it.png       79         79
# 15272  https://cdn.sofifa.net/flags/jp.png       56         56
#
#                            Club                                   Club Logo  \
# 17636  FC Dinamo 1948 Bucureşti  https://cdn.sofifa.net/teams/100757/30.png
# 13536        FC Farul Constanța  https://cdn.sofifa.net/teams/110075/30.png
# 17544    Vancouver Whitecaps FC  https://cdn.sofifa.net/teams/101112/30.png
# 13509        Universitatea Cluj  https://cdn.sofifa.net/teams/110751/30.png
# 15654              Guangzhou FC  https://cdn.sofifa.net/teams/111839/30.png
# ...                         ...                                         ...
# 16036    San Lorenzo de Almagro    https://cdn.sofifa.net/teams/1013/30.png
# 3143     Montpellier Hérault SC      https://cdn.sofifa.net/teams/70/30.png
# 17257           Helsingborgs IF     https://cdn.sofifa.net/teams/432/30.png
# 15375                     Parma      https://cdn.sofifa.net/teams/50/30.png
# 15272               Yokohama FC  https://cdn.sofifa.net/teams/113197/30.png
#
#        ... Real Face                     Position        Joined Loaned From  \
# 17636  ...        No  <span class="pos pos29">RES   Jun 1, 2021         NaN
# 13536  ...        No  <span class="pos pos29">RES   Jun 1, 2022         NaN
# 17544  ...        No  <span class="pos pos28">SUB  May 21, 2022         NaN
# 13509  ...        No  <span class="pos pos29">RES   Jul 1, 2020         NaN
# 15654  ...        No  <span class="pos pos29">RES   May 1, 2022         NaN
# ...    ...       ...                          ...           ...         ...
# 16036  ...        No    <span class="pos pos0">GK  Apr 25, 2013         NaN
# 3143   ...       Yes   <span class="pos pos4">RCB   Aug 1, 2011         NaN
# 17257  ...        No  <span class="pos pos28">SUB  Apr 21, 2016         NaN
# 15375  ...       Yes    <span class="pos pos0">GK   Jul 1, 2021         NaN
# 15272  ...        No  <span class="pos pos29">RES   Jul 1, 2005         NaN
#
#        Contract Valid Until  Height  Weight Release Clause Kit Number  \
# 17636                  2025   190cm    77kg          €306K       34.0
# 13536                  2024   186cm    72kg          €823K       26.0
# 17544                  2023   185cm    74kg          €325K       50.0
# 13509                  2023   175cm    65kg          €353K       19.0
# 15654                  2024   175cm    64kg          €175K       16.0
# ...                     ...     ...     ...            ...        ...
# 16036                  2022   183cm    84kg          €375K       12.0
# 3143                   2021   180cm    78kg            NaN        4.0
# 17257                  2022   187cm    85kg            NaN       39.0
# 15375                  2024   192cm    92kg            €3M        1.0
# 15272                  2022   177cm    72kg            NaN       11.0
#
#       Best Overall Rating
# 17636                 NaN
# 13536                 NaN
# 17544                 NaN
# 13509                 NaN
# 15654                 NaN
# ...                   ...
# 16036                 NaN
# 3143                  NaN
# 17257                 NaN
# 15375                 NaN
# 15272                 NaN
#
# [17660 rows x 29 columns]

# %% [markdown]
# `-` 예시2: 나이가 많은 순서대로 정렬

# %%
df.sort_values(by='Age',ascending=False)
# Out:
#            ID             Name  Age  \
# 15272  254704      22 K. Miura   54
# 15375    1179        G. Buffon   44
# 17257     645  17 D. Andersson   43
# 16036  216692       S. Torrico   42
# 3143   153260        21 Hilton   42
# ...       ...              ...  ...
# 12942  265596       22 S. Gale   16
# 15242  267858      22 L. Noian   16
# 12798  259182  21 G. Plumbuitu   16
# 15382  268768  22 Kim Dae Hwan   16
# 17636  263636    22 D. Oncescu   15
#
#                                                   Photo     Nationality  \
# 15272  https://cdn.sofifa.net/players/254/704/22_60.png           Japan
# 15375  https://cdn.sofifa.net/players/001/179/23_60.png           Italy
# 17257  https://cdn.sofifa.net/players/000/645/17_60.png          Sweden
# 16036  https://cdn.sofifa.net/players/216/692/23_60.png       Argentina
# 3143   https://cdn.sofifa.net/players/153/260/21_60.png          Brazil
# ...                                                 ...             ...
# 12942  https://cdn.sofifa.net/players/265/596/22_60.png         England
# 15242  https://cdn.sofifa.net/players/267/858/22_60.png         Romania
# 12798  https://cdn.sofifa.net/players/259/182/21_60.png         Romania
# 15382  https://cdn.sofifa.net/players/268/768/22_60.png  Korea Republic
# 17636  https://cdn.sofifa.net/players/263/636/22_60.png         Romania
#
#                                           Flag  Overall  Potential  \
# 15272      https://cdn.sofifa.net/flags/jp.png       56         56
# 15375      https://cdn.sofifa.net/flags/it.png       79         79
# 17257      https://cdn.sofifa.net/flags/se.png       57         57
# 16036      https://cdn.sofifa.net/flags/ar.png       72         72
# 3143       https://cdn.sofifa.net/flags/br.png       75         75
# ...                                        ...      ...        ...
# 12942  https://cdn.sofifa.net/flags/gb-eng.png       52         67
# 15242      https://cdn.sofifa.net/flags/ro.png       51         71
# 12798      https://cdn.sofifa.net/flags/ro.png       56         70
# 15382      https://cdn.sofifa.net/flags/kr.png       50         68
# 17636      https://cdn.sofifa.net/flags/ro.png       50         72
#
#                            Club                                   Club Logo  \
# 15272               Yokohama FC  https://cdn.sofifa.net/teams/113197/30.png
# 15375                     Parma      https://cdn.sofifa.net/teams/50/30.png
# 17257           Helsingborgs IF     https://cdn.sofifa.net/teams/432/30.png
# 16036    San Lorenzo de Almagro    https://cdn.sofifa.net/teams/1013/30.png
# 3143     Montpellier Hérault SC      https://cdn.sofifa.net/teams/70/30.png
# ...                         ...                                         ...
# 12942                Gillingham    https://cdn.sofifa.net/teams/1802/30.png
# 15242          Gaz Metan Mediaş  https://cdn.sofifa.net/teams/112637/30.png
# 12798          Gaz Metan Mediaş  https://cdn.sofifa.net/teams/112637/30.png
# 15382            Jeju United FC    https://cdn.sofifa.net/teams/1478/30.png
# 17636  FC Dinamo 1948 Bucureşti  https://cdn.sofifa.net/teams/100757/30.png
#
#        ... Real Face                     Position        Joined Loaned From  \
# 15272  ...        No  <span class="pos pos29">RES   Jul 1, 2005         NaN
# 15375  ...       Yes    <span class="pos pos0">GK   Jul 1, 2021         NaN
# 17257  ...        No  <span class="pos pos28">SUB  Apr 21, 2016         NaN
# 16036  ...        No    <span class="pos pos0">GK  Apr 25, 2013         NaN
# 3143   ...       Yes   <span class="pos pos4">RCB   Aug 1, 2011         NaN
# ...    ...       ...                          ...           ...         ...
# 12942  ...        No  <span class="pos pos29">RES  Nov 18, 2021         NaN
# 15242  ...        No  <span class="pos pos28">SUB  Feb 25, 2022         NaN
# 12798  ...        No  <span class="pos pos28">SUB  Sep 25, 2020         NaN
# 15382  ...        No  <span class="pos pos29">RES   Mar 4, 2022         NaN
# 17636  ...        No  <span class="pos pos29">RES   Jun 1, 2021         NaN
#
#        Contract Valid Until  Height  Weight Release Clause Kit Number  \
# 15272                  2022   177cm    72kg            NaN       11.0
# 15375                  2024   192cm    92kg            €3M        1.0
# 17257                  2022   187cm    85kg            NaN       39.0
# 16036                  2022   183cm    84kg          €375K       12.0
# 3143                   2021   180cm    78kg            NaN        4.0
# ...                     ...     ...     ...            ...        ...
# 12942                  2022   180cm    73kg          €404K       29.0
# 15242                  2026   180cm    70kg          €376K       77.0
# 12798                  2023   176cm    72kg          €642K       26.0
# 15382                  2026   172cm    67kg          €206K       32.0
# 17636                  2025   190cm    77kg          €306K       34.0
#
#       Best Overall Rating
# 15272                 NaN
# 15375                 NaN
# 17257                 NaN
# 16036                 NaN
# 3143                  NaN
# ...                   ...
# 12942                 NaN
# 15242                 NaN
# 12798                 NaN
# 15382                 NaN
# 17636                 NaN
#
# [17660 rows x 29 columns]

# %% [markdown]
# `-` 예시3: 능력치가 좋은 순서대로 정렬

# %%
df.sort_values(by='Overall',ascending=False)
# Out:
#            ID               Name  Age  \
# 41     188545     R. Lewandowski   33
# 56     158023           L. Messi   35
# 3      192985       K. De Bruyne   31
# 75     231747          K. Mbappé   23
# 124    165153         K. Benzema   34
# ...       ...                ...  ...
# 14353  269032      22 Chen Zeshi   16
# 16215  268279     22 J. Looschen   24
# 14634  269038   22 Zhang Wenxuan   16
# 16042  255283  20 Kim Yeong Geun   22
# 17618  168933       07 I. Paskov   33
#
#                                                   Photo     Nationality  \
# 41     https://cdn.sofifa.net/players/188/545/23_60.png          Poland
# 56     https://cdn.sofifa.net/players/158/023/23_60.png       Argentina
# 3      https://cdn.sofifa.net/players/192/985/23_60.png         Belgium
# 75     https://cdn.sofifa.net/players/231/747/23_60.png          France
# 124    https://cdn.sofifa.net/players/165/153/23_60.png          France
# ...                                                 ...             ...
# 14353  https://cdn.sofifa.net/players/269/032/22_60.png        China PR
# 16215  https://cdn.sofifa.net/players/268/279/22_60.png         Germany
# 14634  https://cdn.sofifa.net/players/269/038/22_60.png        China PR
# 16042  https://cdn.sofifa.net/players/255/283/20_60.png  Korea Republic
# 17618  https://cdn.sofifa.net/players/168/933/07_60.png        Bulgaria
#
#                                       Flag  Overall  Potential  \
# 41     https://cdn.sofifa.net/flags/pl.png       91         91
# 56     https://cdn.sofifa.net/flags/ar.png       91         91
# 3      https://cdn.sofifa.net/flags/be.png       91         91
# 75     https://cdn.sofifa.net/flags/fr.png       91         95
# 124    https://cdn.sofifa.net/flags/fr.png       91         91
# ...                                    ...      ...        ...
# 14353  https://cdn.sofifa.net/flags/cn.png       45         55
# 16215  https://cdn.sofifa.net/flags/de.png       44         47
# 14634  https://cdn.sofifa.net/flags/cn.png       44         59
# 16042  https://cdn.sofifa.net/flags/kr.png       44         49
# 17618  https://cdn.sofifa.net/flags/bg.png       43         42
#
#                       Club                                   Club Logo  ...  \
# 41            FC Barcelona     https://cdn.sofifa.net/teams/241/30.png  ...
# 56     Paris Saint-Germain      https://cdn.sofifa.net/teams/73/30.png  ...
# 3          Manchester City      https://cdn.sofifa.net/teams/10/30.png  ...
# 75     Paris Saint-Germain      https://cdn.sofifa.net/teams/73/30.png  ...
# 124         Real Madrid CF     https://cdn.sofifa.net/teams/243/30.png  ...
# ...                    ...                                         ...  ...
# 14353     Shandong Taishan  https://cdn.sofifa.net/teams/111724/30.png  ...
# 16215            SV Meppen  https://cdn.sofifa.net/teams/110597/30.png  ...
# 14634         Guangzhou FC  https://cdn.sofifa.net/teams/111839/30.png  ...
# 16042         Gyeongnam FC  https://cdn.sofifa.net/teams/111588/30.png  ...
# 17618                  NaN         https://cdn.sofifa.net/flags/bg.png  ...
#
#       Real Face                     Position        Joined Loaned From  \
# 41          Yes   <span class="pos pos25">ST  Jul 18, 2022         NaN
# 56          Yes   <span class="pos pos23">RW  Aug 10, 2021         NaN
# 3           Yes  <span class="pos pos13">RCM  Aug 30, 2015         NaN
# 75          Yes   <span class="pos pos25">ST   Jul 1, 2018         NaN
# 124         Yes   <span class="pos pos21">CF   Jul 9, 2009         NaN
# ...         ...                          ...           ...         ...
# 14353        No  <span class="pos pos29">RES   May 1, 2022         NaN
# 16215        No  <span class="pos pos29">RES  Mar 19, 2022         NaN
# 14634        No  <span class="pos pos29">RES   May 1, 2022         NaN
# 16042        No  <span class="pos pos29">RES   Jan 9, 2020         NaN
# 17618       NaN  <span class="pos pos28">SUB           NaN         NaN
#
#        Contract Valid Until  Height  Weight Release Clause Kit Number  \
# 41                     2025   185cm    81kg        €172.2M        9.0
# 56                     2023   169cm    67kg         €99.9M       30.0
# 3                      2025   181cm    70kg        €198.9M       17.0
# 75                     2025   182cm    73kg        €366.7M        7.0
# 124                    2023   185cm    81kg        €131.2M        9.0
# ...                     ...     ...     ...            ...        ...
# 14353                  2024   180cm    70kg          €175K       38.0
# 16215                  2026   178cm    78kg           €92K       42.0
# 14634                  2022   175cm    70kg          €239K       29.0
# 16042                  2020   174cm    71kg           €53K       43.0
# 17618                   NaN   184cm    79kg            NaN       24.0
#
#       Best Overall Rating
# 41                    NaN
# 56                    NaN
# 3                     NaN
# 75                    NaN
# 124                   NaN
# ...                   ...
# 14353                 NaN
# 16215                 NaN
# 14634                 NaN
# 16042                 NaN
# 17618                 NaN
#
# [17660 rows x 29 columns]

# %% [markdown]
# ### E. `df.info()`

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17660 entries, 0 to 17659
# Data columns (total 29 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        17660 non-null  int64
#  1   Name                      17660 non-null  object
#  2   Age                       17660 non-null  int64
#  3   Photo                     17660 non-null  object
#  4   Nationality               17660 non-null  object
#  5   Flag                      17660 non-null  object
#  6   Overall                   17660 non-null  int64
#  7   Potential                 17660 non-null  int64
#  8   Club                      17449 non-null  object
#  9   Club Logo                 17660 non-null  object
#  10  Value                     17660 non-null  object
#  11  Wage                      17660 non-null  object
#  12  Special                   17660 non-null  int64
#  13  Preferred Foot            17660 non-null  object
#  14  International Reputation  17660 non-null  float64
#  15  Weak Foot                 17660 non-null  float64
#  16  Skill Moves               17660 non-null  float64
#  17  Work Rate                 17660 non-null  object
#  18  Body Type                 17622 non-null  object
#  19  Real Face                 17622 non-null  object
#  20  Position                  17625 non-null  object
#  21  Joined                    16562 non-null  object
#  22  Loaned From               694 non-null    object
#  23  Contract Valid Until      17299 non-null  object
#  24  Height                    17660 non-null  object
#  25  Weight                    17660 non-null  object
#  26  Release Clause            16509 non-null  object
#  27  Kit Number                17625 non-null  float64
#  28  Best Overall Rating       21 non-null     object
# dtypes: float64(4), int64(5), object(20)
# memory usage: 3.9+ MB

# %% [markdown]
# ### F. 기본 query

# %% [markdown]
# `-` 예제: 나이가 20-25인 선수들을 출력

# %%
df.query("Age >= 20 and Age <= 25")
df.query("20 <= Age <= 25")
# Out:
#            ID                 Name  Age  \
# 4      224232           N. Barella   25
# 17     228702           F. de Jong   25
# 21     231281  T. Alexander-Arnold   23
# 23     235212            A. Hakimi   23
# 26     241096            S. Tonali   22
# ...       ...                  ...  ...
# 17644  265760         22 N. Sorras   23
# 17646  270906              R. Badu   20
# 17653  253186          22 S. Booth   20
# 17657  270567             A. Demir   25
# 17659  256376      21 F. Jakobsson   20
#
#                                                   Photo  Nationality  \
# 4      https://cdn.sofifa.net/players/224/232/23_60.png        Italy
# 17     https://cdn.sofifa.net/players/228/702/23_60.png  Netherlands
# 21     https://cdn.sofifa.net/players/231/281/23_60.png      England
# 23     https://cdn.sofifa.net/players/235/212/23_60.png      Morocco
# 26     https://cdn.sofifa.net/players/241/096/23_60.png        Italy
# ...                                                 ...          ...
# 17644  https://cdn.sofifa.net/players/265/760/22_60.png    Australia
# 17646  https://cdn.sofifa.net/players/270/906/23_60.png      Belgium
# 17653  https://cdn.sofifa.net/players/253/186/22_60.png      England
# 17657  https://cdn.sofifa.net/players/270/567/23_60.png       Turkey
# 17659  https://cdn.sofifa.net/players/256/376/21_60.png       Sweden
#
#                                           Flag  Overall  Potential  \
# 4          https://cdn.sofifa.net/flags/it.png       86         89
# 17         https://cdn.sofifa.net/flags/nl.png       87         92
# 21     https://cdn.sofifa.net/flags/gb-eng.png       87         90
# 23         https://cdn.sofifa.net/flags/ma.png       84         87
# 26         https://cdn.sofifa.net/flags/it.png       84         90
# ...                                        ...      ...        ...
# 17644      https://cdn.sofifa.net/flags/au.png       50         57
# 17646      https://cdn.sofifa.net/flags/be.png       52         61
# 17653  https://cdn.sofifa.net/flags/gb-eng.png       51         60
# 17657      https://cdn.sofifa.net/flags/tr.png       51         56
# 17659      https://cdn.sofifa.net/flags/se.png       50         61
#
#                       Club                                   Club Logo  ...  \
# 4                    Inter      https://cdn.sofifa.net/teams/44/30.png  ...
# 17            FC Barcelona     https://cdn.sofifa.net/teams/241/30.png  ...
# 21               Liverpool       https://cdn.sofifa.net/teams/9/30.png  ...
# 23     Paris Saint-Germain      https://cdn.sofifa.net/teams/73/30.png  ...
# 26                AC Milan      https://cdn.sofifa.net/teams/47/30.png  ...
# ...                    ...                                         ...  ...
# 17644          Perth Glory  https://cdn.sofifa.net/teams/111399/30.png  ...
# 17646          KV Oostende     https://cdn.sofifa.net/teams/682/30.png  ...
# 17653      Crewe Alexandra     https://cdn.sofifa.net/teams/121/30.png  ...
# 17657         Ümraniyespor  https://cdn.sofifa.net/teams/113796/30.png  ...
# 17659       IFK Norrköping     https://cdn.sofifa.net/teams/702/30.png  ...
#
#       Real Face                     Position       Joined Loaned From  \
# 4           Yes  <span class="pos pos13">RCM  Sep 1, 2020         NaN
# 17          Yes  <span class="pos pos13">RCM  Jul 1, 2019         NaN
# 21          Yes    <span class="pos pos3">RB  Oct 7, 2015         NaN
# 23          Yes   <span class="pos pos2">RWB  Jul 6, 2021         NaN
# 26          Yes  <span class="pos pos13">RCM  Jul 8, 2021         NaN
# ...         ...                          ...          ...         ...
# 17644        No  <span class="pos pos29">RES  Dec 3, 2021         NaN
# 17646        No  <span class="pos pos28">SUB  Jul 1, 2020         NaN
# 17653        No  <span class="pos pos29">RES  Jul 1, 2019         NaN
# 17657        No  <span class="pos pos29">RES  Jun 6, 2021         NaN
# 17659        No  <span class="pos pos29">RES  Jan 8, 2020         NaN
#
#        Contract Valid Until  Height  Weight Release Clause Kit Number  \
# 4                      2026   172cm    68kg        €154.4M       23.0
# 17                     2026   180cm    74kg        €247.6M       21.0
# 21                     2025   180cm    69kg        €193.5M       66.0
# 23                     2026   181cm    73kg          €103M        2.0
# 26                     2026   181cm    79kg        €118.8M        8.0
# ...                     ...     ...     ...            ...        ...
# 17644                  2021   194cm    80kg          €116K       30.0
# 17646                  2023   190cm    75kg          €248K       91.0
# 17653                  2022   195cm    80kg          €215K       27.0
# 17657                  2023   190cm    82kg          €142K       12.0
# 17659                  2021   186cm    78kg          €131K       30.0
#
#       Best Overall Rating
# 4                     NaN
# 17                    NaN
# 21                    NaN
# 23                    NaN
# 26                    NaN
# ...                   ...
# 17644                 NaN
# 17646                 NaN
# 17653                 NaN
# 17657                 NaN
# 17659                 NaN
#
# [8794 rows x 29 columns]

# %% [markdown]
# `-` 예제: Overall - Potentila이 20이상인 선수를 출력하라

# %%
df.query("Potential - Overall  > 20")
# Out:
#            ID            Name  Age  \
# 4207   269136    22 K. Mainoo   16
# 4532   262242     S. Raebiger   17
# 4981   260144       C. Patino   18
# 5284   266127      22 L. Hall   16
# 5332   259356  C. Chukwuemeka   18
# ...       ...             ...  ...
# 17561  267855    22 S. Bumbar   16
# 17582  261519   21 K. Ersunar   17
# 17599  271112      G. Beavers   17
# 17607  271179      A. Brînzea   16
# 17636  263636   22 D. Oncescu   15
#
#                                                   Photo    Nationality  \
# 4207   https://cdn.sofifa.net/players/269/136/22_60.png        England
# 4532   https://cdn.sofifa.net/players/262/242/23_60.png        Germany
# 4981   https://cdn.sofifa.net/players/260/144/23_60.png        England
# 5284   https://cdn.sofifa.net/players/266/127/22_60.png        England
# 5332   https://cdn.sofifa.net/players/259/356/23_60.png        England
# ...                                                 ...            ...
# 17561  https://cdn.sofifa.net/players/267/855/22_60.png        Romania
# 17582  https://cdn.sofifa.net/players/261/519/21_60.png         Turkey
# 17599  https://cdn.sofifa.net/players/271/112/23_60.png  United States
# 17607  https://cdn.sofifa.net/players/271/179/23_60.png        Romania
# 17636  https://cdn.sofifa.net/players/263/636/22_60.png        Romania
#
#                                           Flag  Overall  Potential  \
# 4207   https://cdn.sofifa.net/flags/gb-eng.png       62         83
# 4532       https://cdn.sofifa.net/flags/de.png       62         84
# 4981   https://cdn.sofifa.net/flags/gb-eng.png       64         85
# 5284   https://cdn.sofifa.net/flags/gb-eng.png       59         80
# 5332   https://cdn.sofifa.net/flags/gb-eng.png       64         86
# ...                                        ...      ...        ...
# 17561      https://cdn.sofifa.net/flags/ro.png       50         73
# 17582      https://cdn.sofifa.net/flags/tr.png       50         71
# 17599      https://cdn.sofifa.net/flags/us.png       52         76
# 17607      https://cdn.sofifa.net/flags/ro.png       48         72
# 17636      https://cdn.sofifa.net/flags/ro.png       50         72
#
#                            Club                                   Club Logo  \
# 4207          Manchester United      https://cdn.sofifa.net/teams/11/30.png
# 4532       SpVgg Greuther Fürth     https://cdn.sofifa.net/teams/165/30.png
# 4981                  Blackpool    https://cdn.sofifa.net/teams/1926/30.png
# 5284                    Chelsea       https://cdn.sofifa.net/teams/5/30.png
# 5332                    Chelsea       https://cdn.sofifa.net/teams/5/30.png
# ...                         ...                                         ...
# 17561          Gaz Metan Mediaş  https://cdn.sofifa.net/teams/112637/30.png
# 17582            Galatasaray SK     https://cdn.sofifa.net/teams/325/30.png
# 17599            Real Salt Lake  https://cdn.sofifa.net/teams/111065/30.png
# 17607    AFC Chindia Târgoviște  https://cdn.sofifa.net/teams/113387/30.png
# 17636  FC Dinamo 1948 Bucureşti  https://cdn.sofifa.net/teams/100757/30.png
#
#        ... Real Face                     Position        Joined  \
# 4207   ...        No  <span class="pos pos29">RES  May 16, 2022
# 4532   ...       Yes  <span class="pos pos28">SUB   Jul 1, 2022
# 4981   ...        No  <span class="pos pos28">SUB           NaN
# 5284   ...        No  <span class="pos pos29">RES   Sep 8, 2021
# 5332   ...       Yes  <span class="pos pos29">RES   Aug 2, 2022
# ...    ...       ...                          ...           ...
# 17561  ...        No    <span class="pos pos0">GK  Feb 25, 2022
# 17582  ...        No  <span class="pos pos29">RES  Sep 14, 2020
# 17599  ...        No  <span class="pos pos28">SUB  Jan 12, 2022
# 17607  ...        No  <span class="pos pos29">RES   Jul 1, 2022
# 17636  ...        No  <span class="pos pos29">RES   Jun 1, 2021
#
#                                   Loaned From  Contract Valid Until  Height  \
# 4207                                      NaN                  2025   175cm
# 4532                                      NaN                  2025   176cm
# 4981   <a href="/team/1/arsenal/">Arsenal</a>          Jun 30, 2023   182cm
# 5284                                      NaN                  2023   180cm
# 5332                                      NaN                  2028   185cm
# ...                                       ...                   ...     ...
# 17561                                     NaN                  2026   176cm
# 17582                                     NaN                  2023   190cm
# 17599                                     NaN                  2023   193cm
# 17607                                     NaN                  2027   187cm
# 17636                                     NaN                  2025   190cm
#
#        Weight Release Clause Kit Number Best Overall Rating
# 4207     80kg          €3.4M       99.0                 NaN
# 4532     70kg          €3.1M        6.0                 NaN
# 4981     75kg            NaN       28.0                 NaN
# 5284     72kg            €2M       75.0                 NaN
# 5332     70kg          €5.4M       30.0                 NaN
# ...       ...            ...        ...                 ...
# 17561    72kg          €306K        1.0                 NaN
# 17582    72kg          €377K       56.0                 NaN
# 17599    83kg          €564K       35.0                 NaN
# 17607    76kg          €306K       99.0                 NaN
# 17636    77kg          €306K       34.0                 NaN
#
# [172 rows x 29 columns]

# %% [markdown]
# `-` 예제3: 한국선수들(=Korea Republic)중 능력치가 높은순서대로 출력하라.

# %%
df.query('Nationality == "Korea Republic"').sort_values(by="Overall",ascending=False)
# Out:
#            ID               Name  Age  \
# 135    200104             H. Son   29
# 3780   237086        Kim Min Jae   25
# 1442    39943         14 J. Park   32
# 1749   226380     Hwang Hee Chan   26
# 5084   211005     Jang Hyeon Soo   30
# ...       ...                ...  ...
# 14478  255277   20 Kim Jun Hyeok   18
# 15630  255279       20 Kim Ho Su   21
# 15834  266315      22 Bae Jae Ik   20
# 15513  266751    22 Jung Ho Yeon   20
# 16042  255283  20 Kim Yeong Geun   22
#
#                                                   Photo     Nationality  \
# 135    https://cdn.sofifa.net/players/200/104/23_60.png  Korea Republic
# 3780   https://cdn.sofifa.net/players/237/086/23_60.png  Korea Republic
# 1442   https://cdn.sofifa.net/players/039/943/14_60.png  Korea Republic
# 1749   https://cdn.sofifa.net/players/226/380/23_60.png  Korea Republic
# 5084   https://cdn.sofifa.net/players/211/005/23_60.png  Korea Republic
# ...                                                 ...             ...
# 14478  https://cdn.sofifa.net/players/255/277/20_60.png  Korea Republic
# 15630  https://cdn.sofifa.net/players/255/279/20_60.png  Korea Republic
# 15834  https://cdn.sofifa.net/players/266/315/22_60.png  Korea Republic
# 15513  https://cdn.sofifa.net/players/266/751/22_60.png  Korea Republic
# 16042  https://cdn.sofifa.net/players/255/283/20_60.png  Korea Republic
#
#                                       Flag  Overall  Potential  \
# 135    https://cdn.sofifa.net/flags/kr.png       89         89
# 3780   https://cdn.sofifa.net/flags/kr.png       79         84
# 1442   https://cdn.sofifa.net/flags/kr.png       78         78
# 1749   https://cdn.sofifa.net/flags/kr.png       77         78
# 5084   https://cdn.sofifa.net/flags/kr.png       75         75
# ...                                    ...      ...        ...
# 14478  https://cdn.sofifa.net/flags/kr.png       47         62
# 15630  https://cdn.sofifa.net/flags/kr.png       47         54
# 15834  https://cdn.sofifa.net/flags/kr.png       47         54
# 15513  https://cdn.sofifa.net/flags/kr.png       45         53
# 16042  https://cdn.sofifa.net/flags/kr.png       44         49
#
#                           Club                                   Club Logo  \
# 135          Tottenham Hotspur      https://cdn.sofifa.net/teams/18/30.png
# 3780                    Napoli      https://cdn.sofifa.net/teams/48/30.png
# 1442                       PSV     https://cdn.sofifa.net/teams/247/30.png
# 1749   Wolverhampton Wanderers     https://cdn.sofifa.net/teams/110/30.png
# 5084                  Al Hilal     https://cdn.sofifa.net/teams/605/30.png
# ...                        ...                                         ...
# 14478             Gyeongnam FC  https://cdn.sofifa.net/teams/111588/30.png
# 15630             Gyeongnam FC  https://cdn.sofifa.net/teams/111588/30.png
# 15834   Jeonbuk Hyundai Motors    https://cdn.sofifa.net/teams/1477/30.png
# 15513               GwangJu FC  https://cdn.sofifa.net/teams/112258/30.png
# 16042             Gyeongnam FC  https://cdn.sofifa.net/teams/111588/30.png
#
#        ... Real Face                     Position        Joined  \
# 135    ...       Yes   <span class="pos pos27">LW  Aug 28, 2015
# 3780   ...        No   <span class="pos pos6">LCB  Jul 28, 2022
# 1442   ...       Yes  <span class="pos pos13">RCM           NaN
# 1749   ...       Yes   <span class="pos pos27">LW   Jul 1, 2022
# 5084   ...        No   <span class="pos pos4">RCB  Jul 13, 2019
# ...    ...       ...                          ...           ...
# 14478  ...        No  <span class="pos pos29">RES   Jan 6, 2020
# 15630  ...        No  <span class="pos pos29">RES   Jan 7, 2020
# 15834  ...        No  <span class="pos pos29">RES   Jan 1, 2022
# 15513  ...        No  <span class="pos pos29">RES  Jan 20, 2022
# 16042  ...        No  <span class="pos pos29">RES   Jan 9, 2020
#
#                                              Loaned From  \
# 135                                                  NaN
# 3780                                                 NaN
# 1442   <a href="/team/15/queens-park-rangers/">Queens...
# 1749                                                 NaN
# 5084                                                 NaN
# ...                                                  ...
# 14478                                                NaN
# 15630                                                NaN
# 15834                                                NaN
# 15513                                                NaN
# 16042                                                NaN
#
#        Contract Valid Until  Height  Weight Release Clause Kit Number  \
# 135                    2025   183cm    78kg        €191.9M        7.0
# 3780                   2025   190cm    81kg         €40.8M        3.0
# 1442           Jun 30, 2014   178cm    73kg            NaN       33.0
# 1749                   2026   177cm    77kg         €24.7M       11.0
# 5084                   2023   183cm    83kg          €7.8M       20.0
# ...                     ...     ...     ...            ...        ...
# 14478                  2020   179cm    70kg          €113K       29.0
# 15630                  2020   181cm    77kg           €58K       42.0
# 15834                  2026   175cm    70kg          €135K       32.0
# 15513                  2026   180cm    73kg          €145K       23.0
# 16042                  2020   174cm    71kg           €53K       43.0
#
#       Best Overall Rating
# 135                   NaN
# 3780                  NaN
# 1442                  NaN
# 1749                  NaN
# 5084                  NaN
# ...                   ...
# 14478                 NaN
# 15630                 NaN
# 15834                 NaN
# 15513                 NaN
# 16042                 NaN
#
# [284 rows x 29 columns]

# %% [markdown]
# ### G. 외부변수를 이용

# %% [markdown]
# `-` 예제: 한국선수들(=Korea Republic)중 능력치가 세계평균 이상인 선수들을 출력하라.

# %%
m= df.Overall.mean()
m
# Out:
# np.float64(63.36959229898075)

# %%
#df.query("Overall > 63.36959229898075 and Nationality == 'Korea Republic'")
#df.query("Overall > Overall.mean() and Nationality == 'Korea Republic'")
df.query("Overall > @m and Nationality == 'Korea Republic'")
# Out:
#            ID               Name  Age  \
# 135    200104             H. Son   29
# 1120   221467      Lee Chang Min   28
# 1322   212260        Hwang Ui Jo   29
# 1395   199231       Kim Tae Hwan   32
# 1442    39943         14 J. Park   32
# 1508   205156    Choi Young Joon   30
# 1597   199236          Hong Chul   31
# 1749   226380     Hwang Hee Chan   26
# 1863   228010   22 Hwang In beom   24
# 2491   182152       Koo Ja Cheol   33
# 2754   243780        Lee Kang In   21
# 2773   155355     Lee Chung Yong   33
# 2850   246937        Um Won Sang   23
# 3036   236586         Kim Jin Ya   24
# 3215   211927    Kwon Chang Hoon   28
# 3372   201528     Kim Young Gwon   32
# 3780   237086        Kim Min Jae   25
# 3788   239138    Jeong Woo Yeong   22
# 3951   212778  22 Kwon Kyung Won   29
# 3993   248188       Song Min Kyu   22
# 4007   243061       Lee Dong Jun   25
# 4233   254980     Seol Young Woo   23
# 4744   212912        Park Ji Soo   28
# 4823   254814         Won Du Jae   24
# 4874   247686       Cho Gue Sung   24
# 5084   211005     Jang Hyeon Soo   30
# 5191   233581        Song Si Woo   28
# 5532   263845    Park Seung Wook   25
# 5838   221756    Lee Gwang Hyeok   26
# 6592   255500        Seo Min Woo   24
# 7148   255917      Goh Young Jun   20
# 7623   231947       22 Oh Se Hun   22
# 9097   227790   Jeong Seung Hyun   28
# 12940  260498       Kwak Yoon Ho   26
# 16002  221912      Kang Hyeon Mu   27
# 16011  212432       Jo Hyeon Woo   30
# 16417  238570      Song Bum Keun   24
#
#                                                   Photo     Nationality  \
# 135    https://cdn.sofifa.net/players/200/104/23_60.png  Korea Republic
# 1120   https://cdn.sofifa.net/players/221/467/23_60.png  Korea Republic
# 1322   https://cdn.sofifa.net/players/212/260/23_60.png  Korea Republic
# 1395   https://cdn.sofifa.net/players/199/231/23_60.png  Korea Republic
# 1442   https://cdn.sofifa.net/players/039/943/14_60.png  Korea Republic
# 1508   https://cdn.sofifa.net/players/205/156/23_60.png  Korea Republic
# 1597   https://cdn.sofifa.net/players/199/236/23_60.png  Korea Republic
# 1749   https://cdn.sofifa.net/players/226/380/23_60.png  Korea Republic
# 1863   https://cdn.sofifa.net/players/228/010/22_60.png  Korea Republic
# 2491   https://cdn.sofifa.net/players/182/152/23_60.png  Korea Republic
# 2754   https://cdn.sofifa.net/players/243/780/23_60.png  Korea Republic
# 2773   https://cdn.sofifa.net/players/155/355/23_60.png  Korea Republic
# 2850   https://cdn.sofifa.net/players/246/937/23_60.png  Korea Republic
# 3036   https://cdn.sofifa.net/players/236/586/23_60.png  Korea Republic
# 3215   https://cdn.sofifa.net/players/211/927/23_60.png  Korea Republic
# 3372   https://cdn.sofifa.net/players/201/528/23_60.png  Korea Republic
# 3780   https://cdn.sofifa.net/players/237/086/23_60.png  Korea Republic
# 3788   https://cdn.sofifa.net/players/239/138/23_60.png  Korea Republic
# 3951   https://cdn.sofifa.net/players/212/778/22_60.png  Korea Republic
# 3993   https://cdn.sofifa.net/players/248/188/23_60.png  Korea Republic
# 4007   https://cdn.sofifa.net/players/243/061/23_60.png  Korea Republic
# 4233   https://cdn.sofifa.net/players/254/980/23_60.png  Korea Republic
# 4744   https://cdn.sofifa.net/players/212/912/23_60.png  Korea Republic
# 4823   https://cdn.sofifa.net/players/254/814/23_60.png  Korea Republic
# 4874   https://cdn.sofifa.net/players/247/686/23_60.png  Korea Republic
# 5084   https://cdn.sofifa.net/players/211/005/23_60.png  Korea Republic
# 5191   https://cdn.sofifa.net/players/233/581/23_60.png  Korea Republic
# 5532   https://cdn.sofifa.net/players/263/845/23_60.png  Korea Republic
# 5838   https://cdn.sofifa.net/players/221/756/23_60.png  Korea Republic
# 6592   https://cdn.sofifa.net/players/255/500/23_60.png  Korea Republic
# 7148   https://cdn.sofifa.net/players/255/917/23_60.png  Korea Republic
# 7623   https://cdn.sofifa.net/players/231/947/22_60.png  Korea Republic
# 9097   https://cdn.sofifa.net/players/227/790/23_60.png  Korea Republic
# 12940  https://cdn.sofifa.net/players/260/498/23_60.png  Korea Republic
# 16002  https://cdn.sofifa.net/players/221/912/23_60.png  Korea Republic
# 16011  https://cdn.sofifa.net/players/212/432/23_60.png  Korea Republic
# 16417  https://cdn.sofifa.net/players/238/570/23_60.png  Korea Republic
#
#                                       Flag  Overall  Potential  \
# 135    https://cdn.sofifa.net/flags/kr.png       89         89
# 1120   https://cdn.sofifa.net/flags/kr.png       72         72
# 1322   https://cdn.sofifa.net/flags/kr.png       75         75
# 1395   https://cdn.sofifa.net/flags/kr.png       72         72
# 1442   https://cdn.sofifa.net/flags/kr.png       78         78
# 1508   https://cdn.sofifa.net/flags/kr.png       72         72
# 1597   https://cdn.sofifa.net/flags/kr.png       71         71
# 1749   https://cdn.sofifa.net/flags/kr.png       77         78
# 1863   https://cdn.sofifa.net/flags/kr.png       72         77
# 2491   https://cdn.sofifa.net/flags/kr.png       66         66
# 2754   https://cdn.sofifa.net/flags/kr.png       73         81
# 2773   https://cdn.sofifa.net/flags/kr.png       70         70
# 2850   https://cdn.sofifa.net/flags/kr.png       72         80
# 3036   https://cdn.sofifa.net/flags/kr.png       66         72
# 3215   https://cdn.sofifa.net/flags/kr.png       66         66
# 3372   https://cdn.sofifa.net/flags/kr.png       71         71
# 3780   https://cdn.sofifa.net/flags/kr.png       79         84
# 3788   https://cdn.sofifa.net/flags/kr.png       72         77
# 3951   https://cdn.sofifa.net/flags/kr.png       72         72
# 3993   https://cdn.sofifa.net/flags/kr.png       68         78
# 4007   https://cdn.sofifa.net/flags/kr.png       70         73
# 4233   https://cdn.sofifa.net/flags/kr.png       68         77
# 4744   https://cdn.sofifa.net/flags/kr.png       69         71
# 4823   https://cdn.sofifa.net/flags/kr.png       68         72
# 4874   https://cdn.sofifa.net/flags/kr.png       69         76
# 5084   https://cdn.sofifa.net/flags/kr.png       75         75
# 5191   https://cdn.sofifa.net/flags/kr.png       65         65
# 5532   https://cdn.sofifa.net/flags/kr.png       67         69
# 5838   https://cdn.sofifa.net/flags/kr.png       65         66
# 6592   https://cdn.sofifa.net/flags/kr.png       65         72
# 7148   https://cdn.sofifa.net/flags/kr.png       64         78
# 7623   https://cdn.sofifa.net/flags/kr.png       67         75
# 9097   https://cdn.sofifa.net/flags/kr.png       72         74
# 12940  https://cdn.sofifa.net/flags/kr.png       64         67
# 16002  https://cdn.sofifa.net/flags/kr.png       70         72
# 16011  https://cdn.sofifa.net/flags/kr.png       73         73
# 16417  https://cdn.sofifa.net/flags/kr.png       70         78
#
#                            Club                                   Club Logo  \
# 135           Tottenham Hotspur      https://cdn.sofifa.net/teams/18/30.png
# 1120             Jeju United FC    https://cdn.sofifa.net/teams/1478/30.png
# 1322   FC Girondins de Bordeaux      https://cdn.sofifa.net/teams/59/30.png
# 1395           Ulsan Hyundai FC    https://cdn.sofifa.net/teams/1473/30.png
# 1442                        PSV     https://cdn.sofifa.net/teams/247/30.png
# 1508             Jeju United FC    https://cdn.sofifa.net/teams/1478/30.png
# 1597                   Daegu FC    https://cdn.sofifa.net/teams/2056/30.png
# 1749    Wolverhampton Wanderers     https://cdn.sofifa.net/teams/110/30.png
# 1863                   FC Seoul     https://cdn.sofifa.net/teams/982/30.png
# 2491             Jeju United FC    https://cdn.sofifa.net/teams/1478/30.png
# 2754               RCD Mallorca     https://cdn.sofifa.net/teams/453/30.png
# 2773           Ulsan Hyundai FC    https://cdn.sofifa.net/teams/1473/30.png
# 2850           Ulsan Hyundai FC    https://cdn.sofifa.net/teams/1473/30.png
# 3036                   FC Seoul     https://cdn.sofifa.net/teams/982/30.png
# 3215           Sangju Sangmu FC    https://cdn.sofifa.net/teams/2055/30.png
# 3372           Ulsan Hyundai FC    https://cdn.sofifa.net/teams/1473/30.png
# 3780                     Napoli      https://cdn.sofifa.net/teams/48/30.png
# 3788        Sport-Club Freiburg      https://cdn.sofifa.net/teams/25/30.png
# 3951                Gamba Osaka  https://cdn.sofifa.net/teams/112093/30.png
# 3993     Jeonbuk Hyundai Motors    https://cdn.sofifa.net/teams/1477/30.png
# 4007                 Hertha BSC     https://cdn.sofifa.net/teams/166/30.png
# 4233           Ulsan Hyundai FC    https://cdn.sofifa.net/teams/1473/30.png
# 4744           Sangju Sangmu FC    https://cdn.sofifa.net/teams/2055/30.png
# 4823           Ulsan Hyundai FC    https://cdn.sofifa.net/teams/1473/30.png
# 4874           Sangju Sangmu FC    https://cdn.sofifa.net/teams/2055/30.png
# 5084                   Al Hilal     https://cdn.sofifa.net/teams/605/30.png
# 5191          Incheon United FC  https://cdn.sofifa.net/teams/110765/30.png
# 5532            Pohang Steelers    https://cdn.sofifa.net/teams/1474/30.png
# 5838            Pohang Steelers    https://cdn.sofifa.net/teams/1474/30.png
# 6592                 Gangwon FC  https://cdn.sofifa.net/teams/112115/30.png
# 7148            Pohang Steelers    https://cdn.sofifa.net/teams/1474/30.png
# 7623            Shimizu S-Pulse  https://cdn.sofifa.net/teams/101149/30.png
# 9097           Sangju Sangmu FC    https://cdn.sofifa.net/teams/2055/30.png
# 12940                  Suwon FC  https://cdn.sofifa.net/teams/112558/30.png
# 16002           Pohang Steelers    https://cdn.sofifa.net/teams/1474/30.png
# 16011          Ulsan Hyundai FC    https://cdn.sofifa.net/teams/1473/30.png
# 16417    Jeonbuk Hyundai Motors    https://cdn.sofifa.net/teams/1477/30.png
#
#        ... Real Face                     Position        Joined  \
# 135    ...       Yes   <span class="pos pos27">LW  Aug 28, 2015
# 1120   ...        No  <span class="pos pos13">RCM   Jan 1, 2016
# 1322   ...        No  <span class="pos pos28">SUB  Jul 18, 2019
# 1395   ...        No    <span class="pos pos3">RB   Feb 2, 2015
# 1442   ...       Yes  <span class="pos pos13">RCM           NaN
# 1508   ...        No  <span class="pos pos15">LCM   Jan 5, 2022
# 1597   ...        No   <span class="pos pos8">LWB   Jan 5, 2022
# 1749   ...       Yes   <span class="pos pos27">LW   Jul 1, 2022
# 1863   ...        No  <span class="pos pos29">RES   Apr 7, 2022
# 2491   ...        No  <span class="pos pos28">SUB   Mar 4, 2022
# 2754   ...        No  <span class="pos pos28">SUB  Aug 30, 2021
# 2773   ...       Yes   <span class="pos pos12">RM   Mar 4, 2020
# 2850   ...        No  <span class="pos pos28">SUB  Feb 20, 2022
# 3036   ...        No  <span class="pos pos28">SUB  Dec 14, 2019
# 3215   ...        No   <span class="pos pos23">RW           NaN
# 3372   ...        No   <span class="pos pos6">LCB  Dec 19, 2021
# 3780   ...        No   <span class="pos pos6">LCB  Jul 28, 2022
# 3788   ...       Yes  <span class="pos pos28">SUB   Jul 1, 2019
# 3951   ...        No   <span class="pos pos6">LCB   Jan 5, 2022
# 3993   ...        No   <span class="pos pos23">RW  Jul 20, 2021
# 4007   ...        No  <span class="pos pos28">SUB  Jan 29, 2022
# 4233   ...        No    <span class="pos pos7">LB   Jan 8, 2020
# 4744   ...        No   <span class="pos pos4">RCB           NaN
# 4823   ...        No   <span class="pos pos9">RDM  Dec 30, 2019
# 4874   ...        No   <span class="pos pos25">ST           NaN
# 5084   ...        No   <span class="pos pos4">RCB  Jul 13, 2019
# 5191   ...        No  <span class="pos pos28">SUB   Jan 1, 2016
# 5532   ...        No   <span class="pos pos4">RCB  Jul 29, 2021
# 5838   ...        No  <span class="pos pos28">SUB   Jan 1, 2014
# 6592   ...        No  <span class="pos pos15">LCM   Jan 6, 2020
# 7148   ...        No  <span class="pos pos18">CAM   Jan 1, 2020
# 7623   ...        No  <span class="pos pos28">SUB  Feb 24, 2022
# 9097   ...        No   <span class="pos pos6">LCB           NaN
# 12940  ...        No  <span class="pos pos28">SUB  Jan 13, 2021
# 16002  ...        No    <span class="pos pos0">GK   Jan 1, 2014
# 16011  ...        No    <span class="pos pos0">GK  Jan 20, 2020
# 16417  ...        No    <span class="pos pos0">GK   Jan 5, 2018
#
#                                              Loaned From  \
# 135                                                  NaN
# 1120                                                 NaN
# 1322                                                 NaN
# 1395                                                 NaN
# 1442   <a href="/team/15/queens-park-rangers/">Queens...
# 1508                                                 NaN
# 1597                                                 NaN
# 1749                                                 NaN
# 1863                                                 NaN
# 2491                                                 NaN
# 2754                                                 NaN
# 2773                                                 NaN
# 2850                                                 NaN
# 3036                                                 NaN
# 3215   <a href="/team/983/suwon-samsung-bluewings/">S...
# 3372                                                 NaN
# 3780                                                 NaN
# 3788                                                 NaN
# 3951                                                 NaN
# 3993                                                 NaN
# 4007                                                 NaN
# 4233                                                 NaN
# 4744   <a href="/team/111839/guangzhou-fc/">Guangzhou...
# 4823                                                 NaN
# 4874   <a href="/team/1477/jeonbuk-hyundai-motors/">J...
# 5084                                                 NaN
# 5191                                                 NaN
# 5532                                                 NaN
# 5838                                                 NaN
# 6592                                                 NaN
# 7148                                                 NaN
# 7623                                                 NaN
# 9097   <a href="/team/1473/ulsan-hyundai-fc/">Ulsan H...
# 12940                                                NaN
# 16002                                                NaN
# 16011                                                NaN
# 16417                                                NaN
#
#        Contract Valid Until  Height  Weight Release Clause Kit Number  \
# 135                    2025   183cm    78kg        €191.9M        7.0
# 1120                   2022   179cm    77kg          €2.9M        8.0
# 1322                   2023   185cm    82kg          €9.9M       18.0
# 1395                   2022   177cm    72kg          €2.1M       23.0
# 1442           Jun 30, 2014   178cm    73kg            NaN       33.0
# 1508                   2026   181cm    76kg          €2.5M        6.0
# 1597                   2022   176cm    70kg          €1.8M       33.0
# 1749                   2026   177cm    77kg         €24.7M       11.0
# 1863                   2022   177cm    70kg          €4.6M       96.0
# 2491                   2025   183cm    79kg          €656K       42.0
# 2754                   2025   173cm    68kg         €16.8M       19.0
# 2773                   2022   180cm    70kg          €1.3M       72.0
# 2850                   2025   171cm    63kg          €7.5M       11.0
# 3036                   2023   177cm    63kg          €1.9M       17.0
# 3215           Jun 26, 2023   173cm    72kg            NaN       26.0
# 3372                   2026   186cm    74kg          €1.6M       19.0
# 3780                   2025   190cm    81kg         €40.8M        3.0
# 3788                   2025   179cm    69kg          €6.4M       29.0
# 3951                   2024   188cm    81kg          €2.5M       20.0
# 3993                   2025   179cm    72kg          €4.1M       21.0
# 4007                   2025   173cm    64kg          €3.7M       30.0
# 4233                   2022   180cm    72kg          €3.9M       66.0
# 4744           Dec 31, 2022   187cm    83kg            NaN       23.0
# 4823                   2022   187cm    80kg          €2.2M       16.0
# 4874            Sep 6, 2022   188cm    77kg            NaN        9.0
# 5084                   2023   183cm    83kg          €7.8M       20.0
# 5191                   2024   174cm    72kg          €906K       19.0
# 5532                   2024   184cm    78kg          €1.6M       14.0
# 5838                   2022   169cm    60kg          €1.1M       22.0
# 6592                   2022   184cm    75kg          €1.9M        4.0
# 7148                   2024   168cm    69kg          €2.6M       11.0
# 7623                   2024   193cm    85kg          €3.3M       20.0
# 9097            Sep 6, 2022   188cm    74kg            NaN       15.0
# 12940                  2022   185cm    83kg          €894K        4.0
# 16002                  2026   185cm    78kg            €2M       31.0
# 16011                  2022   189cm    75kg          €2.6M       21.0
# 16417                  2022   194cm    88kg          €4.7M       31.0
#
#       Best Overall Rating
# 135                   NaN
# 1120                  NaN
# 1322                  NaN
# 1395                  NaN
# 1442                  NaN
# 1508                  NaN
# 1597                  NaN
# 1749                  NaN
# 1863                  NaN
# 2491                  NaN
# 2754                  NaN
# 2773                  NaN
# 2850                  NaN
# 3036                  NaN
# 3215                  NaN
# 3372                  NaN
# 3780                  NaN
# 3788                  NaN
# 3951                  NaN
# 3993                  NaN
# 4007                  NaN
# 4233                  NaN
# 4744                  NaN
# 4823                  NaN
# 4874                  NaN
# 5084                  NaN
# 5191                  NaN
# 5532                  NaN
# 5838                  NaN
# 6592                  NaN
# 7148                  NaN
# 7623                  NaN
# 9097                  NaN
# 12940                 NaN
# 16002                 NaN
# 16011                 NaN
# 16417                 NaN
#
# [37 rows x 29 columns]

# %% [markdown]
# ### H. 열의 이름에 공백이 있을 경우

# %% [markdown]
# `-` 예제: `Skill Moves > 4` 인 선수를 구하라.

# %%
df.query('`Skill Moves` > 4').head(5)
# Out:
#         ID           Name  Age  \
# 19  193082    J. Cuadrado   34
# 27  189509         Thiago   31
# 44  232411      C. Nkunku   24
# 62  233927  Lucas Paquetá   24
# 75  231747      K. Mbappé   23
#
#                                                Photo Nationality  \
# 19  https://cdn.sofifa.net/players/193/082/23_60.png    Colombia
# 27  https://cdn.sofifa.net/players/189/509/23_60.png       Spain
# 44  https://cdn.sofifa.net/players/232/411/23_60.png      France
# 62  https://cdn.sofifa.net/players/233/927/23_60.png      Brazil
# 75  https://cdn.sofifa.net/players/231/747/23_60.png      France
#
#                                    Flag  Overall  Potential  \
# 19  https://cdn.sofifa.net/flags/co.png       83         83
# 27  https://cdn.sofifa.net/flags/es.png       86         86
# 44  https://cdn.sofifa.net/flags/fr.png       86         89
# 62  https://cdn.sofifa.net/flags/br.png       82         87
# 75  https://cdn.sofifa.net/flags/fr.png       91         95
#
#                    Club                                   Club Logo  ...  \
# 19             Juventus      https://cdn.sofifa.net/teams/45/30.png  ...
# 27            Liverpool       https://cdn.sofifa.net/teams/9/30.png  ...
# 44           RB Leipzig  https://cdn.sofifa.net/teams/112172/30.png  ...
# 62   Olympique Lyonnais      https://cdn.sofifa.net/teams/66/30.png  ...
# 75  Paris Saint-Germain      https://cdn.sofifa.net/teams/73/30.png  ...
#
#    Real Face                     Position        Joined Loaned From  \
# 19       Yes    <span class="pos pos3">RB   Jul 1, 2017         NaN
# 27       Yes  <span class="pos pos15">LCM  Sep 18, 2020         NaN
# 44       Yes  <span class="pos pos28">SUB           NaN         NaN
# 62       Yes  <span class="pos pos15">LCM   Oct 1, 2020         NaN
# 75       Yes   <span class="pos pos25">ST   Jul 1, 2018         NaN
#
#     Contract Valid Until  Height  Weight Release Clause Kit Number  \
# 19                  2023   179cm    72kg           €23M       11.0
# 27                  2024   174cm    70kg        €102.7M        6.0
# 44                   NaN   175cm    73kg        €166.9M       12.0
# 62                  2025   180cm    72kg         €90.9M       10.0
# 75                  2025   182cm    73kg        €366.7M        7.0
#
#    Best Overall Rating
# 19                 NaN
# 27                 NaN
# 44                 NaN
# 62                 NaN
# 75                 NaN
#
# [5 rows x 29 columns]

# %% [markdown]
# ### I. 열의 이름 변경

# %% [markdown]
# `# 예제`: 열의 이름 출력하고, 열의 이름중 공백(` `)이 있을 경우 언더바(`_`) 로 바꾸자.

# %% [markdown]
# 컬럼출력

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall',
#        'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Joined', 'Loaned From', 'Contract Valid Until', 'Height', 'Weight',
#        'Release Clause', 'Kit Number', 'Best Overall Rating'],
#       dtype='object')

# %% [markdown]
# (1) `df.columns`에 직접대입

# %%
new_colnames = [l.replace(' ','_') for l in df.columns]

# %%
# df.columns = new_colnames
# df

# %% [markdown]
# (2) `set_axis()` 이용

# %%
df.set_axis(new_colnames,axis=1)
# Out:
#            ID             Name  Age  \
# 0      209658      L. Goretzka   27
# 1      212198  Bruno Fernandes   27
# 2      224334         M. Acuña   30
# 3      192985     K. De Bruyne   31
# 4      224232       N. Barella   25
# ...       ...              ...  ...
# 17655  269526    Deng Xiongtao   19
# 17656  267946   22 Lim Jun Sub   17
# 17657  270567         A. Demir   25
# 17658  256624     21 S. Czajor   18
# 17659  256376  21 F. Jakobsson   20
#
#                                                   Photo     Nationality  \
# 0      https://cdn.sofifa.net/players/209/658/23_60.png         Germany
# 1      https://cdn.sofifa.net/players/212/198/23_60.png        Portugal
# 2      https://cdn.sofifa.net/players/224/334/23_60.png       Argentina
# 3      https://cdn.sofifa.net/players/192/985/23_60.png         Belgium
# 4      https://cdn.sofifa.net/players/224/232/23_60.png           Italy
# ...                                                 ...             ...
# 17655  https://cdn.sofifa.net/players/269/526/23_60.png        China PR
# 17656  https://cdn.sofifa.net/players/267/946/22_60.png  Korea Republic
# 17657  https://cdn.sofifa.net/players/270/567/23_60.png          Turkey
# 17658  https://cdn.sofifa.net/players/256/624/21_60.png          Poland
# 17659  https://cdn.sofifa.net/players/256/376/21_60.png          Sweden
#
#                                       Flag  Overall  Potential  \
# 0      https://cdn.sofifa.net/flags/de.png       87         88
# 1      https://cdn.sofifa.net/flags/pt.png       86         87
# 2      https://cdn.sofifa.net/flags/ar.png       85         85
# 3      https://cdn.sofifa.net/flags/be.png       91         91
# 4      https://cdn.sofifa.net/flags/it.png       86         89
# ...                                    ...      ...        ...
# 17655  https://cdn.sofifa.net/flags/cn.png       48         61
# 17656  https://cdn.sofifa.net/flags/kr.png       48         64
# 17657  https://cdn.sofifa.net/flags/tr.png       51         56
# 17658  https://cdn.sofifa.net/flags/pl.png       50         65
# 17659  https://cdn.sofifa.net/flags/se.png       50         61
#
#                     Club                                   Club_Logo  ...  \
# 0      FC Bayern München      https://cdn.sofifa.net/teams/21/30.png  ...
# 1      Manchester United      https://cdn.sofifa.net/teams/11/30.png  ...
# 2             Sevilla FC     https://cdn.sofifa.net/teams/481/30.png  ...
# 3        Manchester City      https://cdn.sofifa.net/teams/10/30.png  ...
# 4                  Inter      https://cdn.sofifa.net/teams/44/30.png  ...
# ...                  ...                                         ...  ...
# 17655      Meizhou Hakka  https://cdn.sofifa.net/teams/114628/30.png  ...
# 17656     Jeju United FC    https://cdn.sofifa.net/teams/1478/30.png  ...
# 17657       Ümraniyespor  https://cdn.sofifa.net/teams/113796/30.png  ...
# 17658     Fleetwood Town  https://cdn.sofifa.net/teams/112260/30.png  ...
# 17659     IFK Norrköping     https://cdn.sofifa.net/teams/702/30.png  ...
#
#       Real_Face                     Position        Joined Loaned_From  \
# 0           Yes  <span class="pos pos28">SUB   Jul 1, 2018         NaN
# 1           Yes  <span class="pos pos15">LCM  Jan 30, 2020         NaN
# 2            No    <span class="pos pos7">LB  Sep 14, 2020         NaN
# 3           Yes  <span class="pos pos13">RCM  Aug 30, 2015         NaN
# 4           Yes  <span class="pos pos13">RCM   Sep 1, 2020         NaN
# ...         ...                          ...           ...         ...
# 17655        No  <span class="pos pos29">RES  Apr 11, 2022         NaN
# 17656        No  <span class="pos pos29">RES   Jan 1, 2022         NaN
# 17657        No  <span class="pos pos29">RES   Jun 6, 2021         NaN
# 17658        No  <span class="pos pos29">RES   Jan 1, 2020         NaN
# 17659        No  <span class="pos pos29">RES   Jan 8, 2020         NaN
#
#        Contract_Valid_Until  Height  Weight Release_Clause Kit_Number  \
# 0                      2026   189cm    82kg          €157M        8.0
# 1                      2026   179cm    69kg          €155M        8.0
# 2                      2024   172cm    69kg         €97.7M       19.0
# 3                      2025   181cm    70kg        €198.9M       17.0
# 4                      2026   172cm    68kg        €154.4M       23.0
# ...                     ...     ...     ...            ...        ...
# 17655                  2027   190cm    78kg          €218K       35.0
# 17656                  2026   195cm    84kg          €188K       21.0
# 17657                  2023   190cm    82kg          €142K       12.0
# 17658                  2021   187cm    79kg          €214K       40.0
# 17659                  2021   186cm    78kg          €131K       30.0
#
#       Best_Overall_Rating
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 17655                 NaN
# 17656                 NaN
# 17657                 NaN
# 17658                 NaN
# 17659                 NaN
#
# [17660 rows x 29 columns]

# %% [markdown]
# (3) `rename()` 이용

# %%
df.rename({l:l.replace(' ','_') for l in df.columns if ' ' in l},axis=1)
# Out:
#            ID             Name  Age  \
# 0      209658      L. Goretzka   27
# 1      212198  Bruno Fernandes   27
# 2      224334         M. Acuña   30
# 3      192985     K. De Bruyne   31
# 4      224232       N. Barella   25
# ...       ...              ...  ...
# 17655  269526    Deng Xiongtao   19
# 17656  267946   22 Lim Jun Sub   17
# 17657  270567         A. Demir   25
# 17658  256624     21 S. Czajor   18
# 17659  256376  21 F. Jakobsson   20
#
#                                                   Photo     Nationality  \
# 0      https://cdn.sofifa.net/players/209/658/23_60.png         Germany
# 1      https://cdn.sofifa.net/players/212/198/23_60.png        Portugal
# 2      https://cdn.sofifa.net/players/224/334/23_60.png       Argentina
# 3      https://cdn.sofifa.net/players/192/985/23_60.png         Belgium
# 4      https://cdn.sofifa.net/players/224/232/23_60.png           Italy
# ...                                                 ...             ...
# 17655  https://cdn.sofifa.net/players/269/526/23_60.png        China PR
# 17656  https://cdn.sofifa.net/players/267/946/22_60.png  Korea Republic
# 17657  https://cdn.sofifa.net/players/270/567/23_60.png          Turkey
# 17658  https://cdn.sofifa.net/players/256/624/21_60.png          Poland
# 17659  https://cdn.sofifa.net/players/256/376/21_60.png          Sweden
#
#                                       Flag  Overall  Potential  \
# 0      https://cdn.sofifa.net/flags/de.png       87         88
# 1      https://cdn.sofifa.net/flags/pt.png       86         87
# 2      https://cdn.sofifa.net/flags/ar.png       85         85
# 3      https://cdn.sofifa.net/flags/be.png       91         91
# 4      https://cdn.sofifa.net/flags/it.png       86         89
# ...                                    ...      ...        ...
# 17655  https://cdn.sofifa.net/flags/cn.png       48         61
# 17656  https://cdn.sofifa.net/flags/kr.png       48         64
# 17657  https://cdn.sofifa.net/flags/tr.png       51         56
# 17658  https://cdn.sofifa.net/flags/pl.png       50         65
# 17659  https://cdn.sofifa.net/flags/se.png       50         61
#
#                     Club                                   Club_Logo  ...  \
# 0      FC Bayern München      https://cdn.sofifa.net/teams/21/30.png  ...
# 1      Manchester United      https://cdn.sofifa.net/teams/11/30.png  ...
# 2             Sevilla FC     https://cdn.sofifa.net/teams/481/30.png  ...
# 3        Manchester City      https://cdn.sofifa.net/teams/10/30.png  ...
# 4                  Inter      https://cdn.sofifa.net/teams/44/30.png  ...
# ...                  ...                                         ...  ...
# 17655      Meizhou Hakka  https://cdn.sofifa.net/teams/114628/30.png  ...
# 17656     Jeju United FC    https://cdn.sofifa.net/teams/1478/30.png  ...
# 17657       Ümraniyespor  https://cdn.sofifa.net/teams/113796/30.png  ...
# 17658     Fleetwood Town  https://cdn.sofifa.net/teams/112260/30.png  ...
# 17659     IFK Norrköping     https://cdn.sofifa.net/teams/702/30.png  ...
#
#       Real_Face                     Position        Joined Loaned_From  \
# 0           Yes  <span class="pos pos28">SUB   Jul 1, 2018         NaN
# 1           Yes  <span class="pos pos15">LCM  Jan 30, 2020         NaN
# 2            No    <span class="pos pos7">LB  Sep 14, 2020         NaN
# 3           Yes  <span class="pos pos13">RCM  Aug 30, 2015         NaN
# 4           Yes  <span class="pos pos13">RCM   Sep 1, 2020         NaN
# ...         ...                          ...           ...         ...
# 17655        No  <span class="pos pos29">RES  Apr 11, 2022         NaN
# 17656        No  <span class="pos pos29">RES   Jan 1, 2022         NaN
# 17657        No  <span class="pos pos29">RES   Jun 6, 2021         NaN
# 17658        No  <span class="pos pos29">RES   Jan 1, 2020         NaN
# 17659        No  <span class="pos pos29">RES   Jan 8, 2020         NaN
#
#        Contract_Valid_Until  Height  Weight Release_Clause Kit_Number  \
# 0                      2026   189cm    82kg          €157M        8.0
# 1                      2026   179cm    69kg          €155M        8.0
# 2                      2024   172cm    69kg         €97.7M       19.0
# 3                      2025   181cm    70kg        €198.9M       17.0
# 4                      2026   172cm    68kg        €154.4M       23.0
# ...                     ...     ...     ...            ...        ...
# 17655                  2027   190cm    78kg          €218K       35.0
# 17656                  2026   195cm    84kg          €188K       21.0
# 17657                  2023   190cm    82kg          €142K       12.0
# 17658                  2021   187cm    79kg          €214K       40.0
# 17659                  2021   186cm    78kg          €131K       30.0
#
#       Best_Overall_Rating
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 17655                 NaN
# 17656                 NaN
# 17657                 NaN
# 17658                 NaN
# 17659                 NaN
#
# [17660 rows x 29 columns]

# %% [markdown]
# `#`

# %% [markdown]
# ### J. transform column

# %% [markdown]
# `# 예제 `df.Height`열 변환하기 + 변환된 열 할당하기

# %%
df.assign(Height = [int(l.replace("cm","")) for l in df.Height])
# Out:
#            ID             Name  Age  \
# 0      209658      L. Goretzka   27
# 1      212198  Bruno Fernandes   27
# 2      224334         M. Acuña   30
# 3      192985     K. De Bruyne   31
# 4      224232       N. Barella   25
# ...       ...              ...  ...
# 17655  269526    Deng Xiongtao   19
# 17656  267946   22 Lim Jun Sub   17
# 17657  270567         A. Demir   25
# 17658  256624     21 S. Czajor   18
# 17659  256376  21 F. Jakobsson   20
#
#                                                   Photo     Nationality  \
# 0      https://cdn.sofifa.net/players/209/658/23_60.png         Germany
# 1      https://cdn.sofifa.net/players/212/198/23_60.png        Portugal
# 2      https://cdn.sofifa.net/players/224/334/23_60.png       Argentina
# 3      https://cdn.sofifa.net/players/192/985/23_60.png         Belgium
# 4      https://cdn.sofifa.net/players/224/232/23_60.png           Italy
# ...                                                 ...             ...
# 17655  https://cdn.sofifa.net/players/269/526/23_60.png        China PR
# 17656  https://cdn.sofifa.net/players/267/946/22_60.png  Korea Republic
# 17657  https://cdn.sofifa.net/players/270/567/23_60.png          Turkey
# 17658  https://cdn.sofifa.net/players/256/624/21_60.png          Poland
# 17659  https://cdn.sofifa.net/players/256/376/21_60.png          Sweden
#
#                                       Flag  Overall  Potential  \
# 0      https://cdn.sofifa.net/flags/de.png       87         88
# 1      https://cdn.sofifa.net/flags/pt.png       86         87
# 2      https://cdn.sofifa.net/flags/ar.png       85         85
# 3      https://cdn.sofifa.net/flags/be.png       91         91
# 4      https://cdn.sofifa.net/flags/it.png       86         89
# ...                                    ...      ...        ...
# 17655  https://cdn.sofifa.net/flags/cn.png       48         61
# 17656  https://cdn.sofifa.net/flags/kr.png       48         64
# 17657  https://cdn.sofifa.net/flags/tr.png       51         56
# 17658  https://cdn.sofifa.net/flags/pl.png       50         65
# 17659  https://cdn.sofifa.net/flags/se.png       50         61
#
#                     Club                                   Club Logo  ...  \
# 0      FC Bayern München      https://cdn.sofifa.net/teams/21/30.png  ...
# 1      Manchester United      https://cdn.sofifa.net/teams/11/30.png  ...
# 2             Sevilla FC     https://cdn.sofifa.net/teams/481/30.png  ...
# 3        Manchester City      https://cdn.sofifa.net/teams/10/30.png  ...
# 4                  Inter      https://cdn.sofifa.net/teams/44/30.png  ...
# ...                  ...                                         ...  ...
# 17655      Meizhou Hakka  https://cdn.sofifa.net/teams/114628/30.png  ...
# 17656     Jeju United FC    https://cdn.sofifa.net/teams/1478/30.png  ...
# 17657       Ümraniyespor  https://cdn.sofifa.net/teams/113796/30.png  ...
# 17658     Fleetwood Town  https://cdn.sofifa.net/teams/112260/30.png  ...
# 17659     IFK Norrköping     https://cdn.sofifa.net/teams/702/30.png  ...
#
#       Real Face                     Position        Joined Loaned From  \
# 0           Yes  <span class="pos pos28">SUB   Jul 1, 2018         NaN
# 1           Yes  <span class="pos pos15">LCM  Jan 30, 2020         NaN
# 2            No    <span class="pos pos7">LB  Sep 14, 2020         NaN
# 3           Yes  <span class="pos pos13">RCM  Aug 30, 2015         NaN
# 4           Yes  <span class="pos pos13">RCM   Sep 1, 2020         NaN
# ...         ...                          ...           ...         ...
# 17655        No  <span class="pos pos29">RES  Apr 11, 2022         NaN
# 17656        No  <span class="pos pos29">RES   Jan 1, 2022         NaN
# 17657        No  <span class="pos pos29">RES   Jun 6, 2021         NaN
# 17658        No  <span class="pos pos29">RES   Jan 1, 2020         NaN
# 17659        No  <span class="pos pos29">RES   Jan 8, 2020         NaN
#
#        Contract Valid Until  Height  Weight Release Clause Kit Number  \
# 0                      2026     189    82kg          €157M        8.0
# 1                      2026     179    69kg          €155M        8.0
# 2                      2024     172    69kg         €97.7M       19.0
# 3                      2025     181    70kg        €198.9M       17.0
# 4                      2026     172    68kg        €154.4M       23.0
# ...                     ...     ...     ...            ...        ...
# 17655                  2027     190    78kg          €218K       35.0
# 17656                  2026     195    84kg          €188K       21.0
# 17657                  2023     190    82kg          €142K       12.0
# 17658                  2021     187    79kg          €214K       40.0
# 17659                  2021     186    78kg          €131K       30.0
#
#       Best Overall Rating
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 17655                 NaN
# 17656                 NaN
# 17657                 NaN
# 17658                 NaN
# 17659                 NaN
#
# [17660 rows x 29 columns]

# %% [markdown]
# ## 3. Pandas: 할당

# %%
np.random.seed(43052)
att = np.random.choice(np.arange(10,21)*5,20)
rep = np.random.choice(np.arange(5,21)*5,20)
mid = np.random.choice(np.arange(0,21)*5,20)
fin = np.random.choice(np.arange(0,21)*5,20)
df = pd.DataFrame({'att':att,'rep':rep,'mid':mid,'fin':fin})
df
# Out:
#     att  rep  mid  fin
# 0    65   55   50   40
# 1    95  100   50   80
# 2    65   90   60   30
# 3    55   80   75   80
# 4    80   30   30  100
# 5    75   40  100   15
# 6    65   45   45   90
# 7    60   60   25    0
# 8    95   65   20   10
# 9    90   80   80   20
# 10   55   75   35   25
# 11   95   95   45    0
# 12   95   55   15   35
# 13   50   80   40   30
# 14   50   55   15   85
# 15   95   30   30   95
# 16   50   50   45   10
# 17   65   55   15   45
# 18   70   70   40   35
# 19   90   90   80   90

# %% [markdown]
# ### A. `df.assign()`

# %% [markdown]
# `-` 예시: `total = att*0.1 + rep*0.2 + mid*0.35 + fin*0.35` 를 계산하여 할당

# %%
df.assign(total = df.att*0.1 + df.rep*0.2 + df.mid*0.35 + df.fin*0.35)
# Out:
#     att  rep  mid  fin  total
# 0    65   55   50   40  49.00
# 1    95  100   50   80  75.00
# 2    65   90   60   30  56.00
# 3    55   80   75   80  75.75
# 4    80   30   30  100  59.50
# 5    75   40  100   15  55.75
# 6    65   45   45   90  62.75
# 7    60   60   25    0  26.75
# 8    95   65   20   10  33.00
# 9    90   80   80   20  60.00
# 10   55   75   35   25  41.50
# 11   95   95   45    0  44.25
# 12   95   55   15   35  38.00
# 13   50   80   40   30  45.50
# 14   50   55   15   85  51.00
# 15   95   30   30   95  59.25
# 16   50   50   45   10  34.25
# 17   65   55   15   45  38.50
# 18   70   70   40   35  47.25
# 19   90   90   80   90  86.50

# %% [markdown]
# > Note: 이 방법은 df원본을 손상시키지 않음

# %% [markdown]
# ### B. `df.eval()`

# %% [markdown]
# `-` 예시: `total = att*0.1 + rep*0.2 + mid*0.35 + fin*0.35` 를 계산하여 할당

# %%
df.eval("total = att*0.1 + rep*0.2 + mid*0.35 + fin*0.35")
# Out:
#     att  rep  mid  fin  total
# 0    65   55   50   40  49.00
# 1    95  100   50   80  75.00
# 2    65   90   60   30  56.00
# 3    55   80   75   80  75.75
# 4    80   30   30  100  59.50
# 5    75   40  100   15  55.75
# 6    65   45   45   90  62.75
# 7    60   60   25    0  26.75
# 8    95   65   20   10  33.00
# 9    90   80   80   20  60.00
# 10   55   75   35   25  41.50
# 11   95   95   45    0  44.25
# 12   95   55   15   35  38.00
# 13   50   80   40   30  45.50
# 14   50   55   15   85  51.00
# 15   95   30   30   95  59.25
# 16   50   50   45   10  34.25
# 17   65   55   15   45  38.50
# 18   70   70   40   35  47.25
# 19   90   90   80   90  86.50

# %% [markdown]
# > Note: 이 방법은 df원본을 손상시키지 않음

# %% [markdown]
# ### C. `df[colname] = xxx`

# %% [markdown]
# `-` 예시: `total = att*0.1 + rep*0.2 + mid*0.35 + fin*0.35` 를 계산하여 할당.

# %%
df['total'] = df.att*0.1 + df.rep*0.2 + df.mid*0.35 + df.fin*0.35
df
# Out:
#     att  rep  mid  fin  total
# 0    65   55   50   40  49.00
# 1    95  100   50   80  75.00
# 2    65   90   60   30  56.00
# 3    55   80   75   80  75.75
# 4    80   30   30  100  59.50
# 5    75   40  100   15  55.75
# 6    65   45   45   90  62.75
# 7    60   60   25    0  26.75
# 8    95   65   20   10  33.00
# 9    90   80   80   20  60.00
# 10   55   75   35   25  41.50
# 11   95   95   45    0  44.25
# 12   95   55   15   35  38.00
# 13   50   80   40   30  45.50
# 14   50   55   15   85  51.00
# 15   95   30   30   95  59.25
# 16   50   50   45   10  34.25
# 17   65   55   15   45  38.50
# 18   70   70   40   35  47.25
# 19   90   90   80   90  86.50

# %% [markdown]
# > Note: 이 방법은 df를 영구적으로 변화시킴
