# %% [raw]
# ---
# title: "기말고사 - Python"
# author: "최규빈"
# date: "06/15/2025"
# draft: false
# ---

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 1. 타이타닉

# %%
df = pd.read_csv("titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# `(1)` 전체생존률을 구하여라.

# %% [markdown]
# `(2)` 남성과 여성, 어떤 성별의 생존률이 더 높은가?

# %% [markdown]
# `(3)` 아래를 잘 읽고 데이터를 올바르게 분석한 이를 모두 고르라.

# %% [markdown]
# - 다호: 남성은 562명, 여성은 294명 탑승했어.
# - 소윤: 항구(Embarked)별로 남성과 여성의 탑승비율을 살펴보는것도 흥미로워. 항구 C,Q는 남성과 여성이 비슷하게 탑승한 반면, 항구 S에서는 남성이 더 많이 탑승했지.
# - 수호: 성별에 따라 생존률이 차이가 나는데, Pclass에 따라서도 생존률이 차이가 나. 특히 1등석과 3등석 탑승자는 생존률은 40% 이상 차이나.
# - 사라: "나는 SibSp(함께 탑승한 형제자매나 배우자 수)와 Parch(함께 탑승한 부모나 자녀 수)에 주목했어. 이 둘을 더한 다음 본인을 포함하면 SibSp + Parch + 1, 즉 Family Size를 구할 수 있지. 이걸 기준으로 생존률을 살펴봤는데, Family Size가 4인 경우에 생존률이 가장 높았어. 너무 많지도, 너무 적지도 않은 가족 규모가 생존에 유리했던 것 같아."
# - 줄리: 난 연령별 생존률을 조사했지. `pd.qcut(df.Age, q=8)`을 이용해서 연령을 8개의 구간으로 나누고 조사해봤는데, 가장 나이가 어린 그룹의 생존률이 높았어. 그리고 그다음으로 생존률이 높은 그룹은 가장 나이가 많은 그룹이었지. 아무래도 노약자를 배려한것이 아닐까?

# %% [markdown]
# ## 2. FIFA

# %%
df = pd.read_csv("FIFA22_official_data.csv").drop(['Loaned From','Marking'],axis=1).dropna().reset_index(drop=True)
df
# Out:
#            ID             Name  Age  \
# 0      212198  Bruno Fernandes   26
# 1      209658      L. Goretzka   26
# 2      176580        L. Suárez   34
# 3      192985     K. De Bruyne   30
# 4      224334         M. Acuña   29
# ...       ...              ...  ...
# 14393  259718      F. Gebhardt   19
# 14394  251433          B. Voll   20
# 14395  262846         �. Dobre   20
# 14396  241317   21 Xue Qinghao   19
# 14397  259646        A. Shaikh   18
#
#                                                   Photo Nationality  \
# 0      https://cdn.sofifa.com/players/212/198/22_60.png    Portugal
# 1      https://cdn.sofifa.com/players/209/658/22_60.png     Germany
# 2      https://cdn.sofifa.com/players/176/580/22_60.png     Uruguay
# 3      https://cdn.sofifa.com/players/192/985/22_60.png     Belgium
# 4      https://cdn.sofifa.com/players/224/334/22_60.png   Argentina
# ...                                                 ...         ...
# 14393  https://cdn.sofifa.com/players/259/718/22_60.png     Germany
# 14394  https://cdn.sofifa.com/players/251/433/22_60.png     Germany
# 14395  https://cdn.sofifa.com/players/262/846/22_60.png     Romania
# 14396  https://cdn.sofifa.com/players/241/317/21_60.png    China PR
# 14397  https://cdn.sofifa.com/players/259/646/22_60.png       India
#
#                                       Flag  Overall  Potential  \
# 0      https://cdn.sofifa.com/flags/pt.png       88         89
# 1      https://cdn.sofifa.com/flags/de.png       87         88
# 2      https://cdn.sofifa.com/flags/uy.png       88         88
# 3      https://cdn.sofifa.com/flags/be.png       91         91
# 4      https://cdn.sofifa.com/flags/ar.png       84         84
# ...                                    ...      ...        ...
# 14393  https://cdn.sofifa.com/flags/de.png       52         66
# 14394  https://cdn.sofifa.com/flags/de.png       58         69
# 14395  https://cdn.sofifa.com/flags/ro.png       53         63
# 14396  https://cdn.sofifa.com/flags/cn.png       47         60
# 14397  https://cdn.sofifa.com/flags/in.png       47         67
#
#                         Club                                   Club Logo  ...  \
# 0          Manchester United      https://cdn.sofifa.com/teams/11/30.png  ...
# 1          FC Bayern München      https://cdn.sofifa.com/teams/21/30.png  ...
# 2         Atlético de Madrid     https://cdn.sofifa.com/teams/240/30.png  ...
# 3            Manchester City      https://cdn.sofifa.com/teams/10/30.png  ...
# 4                 Sevilla FC     https://cdn.sofifa.com/teams/481/30.png  ...
# ...                      ...                                         ...  ...
# 14393          FC Basel 1893     https://cdn.sofifa.com/teams/896/30.png  ...
# 14394     F.C. Hansa Rostock      https://cdn.sofifa.com/teams/27/30.png  ...
# 14395  FC Academica Clinceni  https://cdn.sofifa.com/teams/113391/30.png  ...
# 14396    Shanghai Shenhua FC  https://cdn.sofifa.com/teams/110955/30.png  ...
# 14397     ATK Mohun Bagan FC  https://cdn.sofifa.com/teams/113146/30.png  ...
#
#       SlidingTackle GKDiving  GKHandling GKKicking  GKPositioning  GKReflexes  \
# 0              65.0     12.0        14.0      15.0            8.0        14.0
# 1              77.0     13.0         8.0      15.0           11.0         9.0
# 2              38.0     27.0        25.0      31.0           33.0        37.0
# 3              53.0     15.0        13.0       5.0           10.0        13.0
# 4              82.0      8.0        14.0      13.0           13.0        14.0
# ...             ...      ...         ...       ...            ...         ...
# 14393          10.0     53.0        45.0      47.0           52.0        57.0
# 14394          10.0     59.0        60.0      56.0           55.0        61.0
# 14395          12.0     57.0        52.0      53.0           48.0        58.0
# 14396           9.0     49.0        48.0      45.0           38.0        52.0
# 14397          13.0     49.0        41.0      39.0           45.0        49.0
#
#        Best Position Best Overall Rating Release Clause DefensiveAwareness
# 0                CAM                88.0        €206.9M               72.0
# 1                 CM                87.0        €160.4M               74.0
# 2                 ST                88.0         €91.2M               42.0
# 3                 CM                91.0        €232.2M               68.0
# 4                 LB                84.0         €77.7M               80.0
# ...              ...                 ...            ...                ...
# 14393             GK                52.0          €361K                6.0
# 14394             GK                58.0          €656K                5.0
# 14395             GK                53.0          €279K                5.0
# 14396             GK                47.0          €223K               21.0
# 14397             GK                47.0          €259K                7.0
#
# [14398 rows x 63 columns]

# %% [markdown]
# `(1)` 아래는 {소속대륙:국가} 정보를 담은 딕셔너리이다.

# %%
continent_dict = {
    'Asia': ['Afghanistan', 'Japan', 'Macau', 'Chinese Taipei', 'Indonesia', 'Korea Republic', 'Kazakhstan', 'Kyrgyzstan', 'Bhutan', 'Philippines', 'Syria', 'China PR', 'Oman', 'Guam', 'Vietnam', 'Jordan', 'Palestine', 'Malaysia', 'Hong Kong', 'Korea DPR', 'Lebanon', 'Uzbekistan', 'India','Iraq', 'Iran', 'Saudi Arabia', 'United Arab Emirates','Australia','Qatar'],
    'Europe': ['Portugal', 'Germany', 'Belgium', 'Netherlands', 'Croatia', 'Spain', 'Austria', 'Italy', 'France', 'Serbia', 'England', 'Poland', 'Ukraine', 'Wales', 'Scotland', 'Czech Republic', 'Slovakia', 'Romania', 'Bosnia and Herzegovina', 'Republic of Ireland', 'Norway', 'Sweden', 'Bulgaria', 'Lithuania', 'Estonia', 'Latvia', 'Liechtenstein','Albania','Denmark','Finland','Greece','Hungary','Iceland','Luxembourg','Northern Ireland','Slovenia','Switzerland','Andorra','Azerbaijan','Belarus','Cyprus','Faroe Islands','Georgia','Kosovo','Malta','Moldova','Montenegro','North Macedonia','Armenia','Gibraltar','Russia','Turkey','Israel'],
    'South America': ['Uruguay', 'Argentina', 'Brazil', 'Chile', 'Colombia', 'Ecuador', 'Paraguay', 'Venezuela', 'Suriname', 'Bolivia','Peru','Guyana'],
    'Africa': ['Egypt', "Côte d'Ivoire", 'Senegal', 'Morocco', 'Ghana', 'Algeria', 'Guinea', 'Mali', 'Congo DR', 'Liberia', 'Cameroon', 'Tunisia', 'Comoros', 'Kenya', 'South Africa', 'Zimbabwe', 'Madagascar', 'Mozambique', 'Equatorial Guinea', 'Congo', 'Burundi', 'Grenada', 'Thailand', 'Togo', 'Sudan', 'Mauritania','Guinea Bissau','Libya','Nigeria','Zambia','Angola','Benin','Burkina Faso','Cape Verde Islands','Central African Republic','Chad','Eritrea','Gabon','Gambia','Mauritius','Namibia','Rwanda','Sierra Leone','South Sudan','São Tomé e Príncipe','Uganda','Niger', 'Tanzania'],
    'North and Central America': ['Antigua and Barbuda', 'Barbados', 'Belize', 'Bermuda', 'Canada', 'Costa Rica', 'Cuba', 'Curacao', 'Dominican Republic', 'El Salvador', 'Guatemala', 'Haiti', 'Honduras', 'Jamaica', 'Mexico', 'Montserrat', 'Panama', 'Puerto Rico', 'Saint Kitts and Nevis', 'Saint Lucia', 'Trinidad and Tobago', 'United States'],
    'Oceania': ['New Zealand', 'Fiji', 'Papua New Guinea','New Caledonia'],
}

# %% [markdown]
# 이 딕셔너리를 활용하여, 각 국가의 대륙(Continent)을 나타내는 새로운 열 Continent를 생성하시오.

# %% [markdown]
# `(2)` 대륙별로 평균연봉을 계산하라. (즉 'Wage'의 평균값을 계산하라)
